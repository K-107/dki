# %%
# !pwd
# Out:
# /

# %%
# %cd /data/FoodDetection/Object_Detection/yolov5-test/yolov5/dataset
# Out:
# /data/FoodDetection/Object_Detection/yolov5-test/yolov5/dataset

# %% [markdown]
# 1. for문으로 데이터프레임 합치기
#
# https://hashcode.co.kr/questions/9219/%ED%8C%8C%EC%9D%B4%EC%8D%AC-for%EB%AC%B8-%EC%97%B0%EB%8F%84%EB%B3%84-%EB%B0%98%EB%B3%B5-%EB%8D%B0%EC%9D%B4%ED%84%B0%ED%94%84%EB%A0%88%EC%9E%84%EC%83%9D%EC%84%B1
#
#
# 2. 데이터프레임 엑셀 시트별 저장
#
# https://sromi.tistory.com/8

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 위의 경로 2곳에서 함수를 각각 실행시켜봐야한다!

# %% [markdown]
# # 함수

# %%
import re
import pandas as pd
import numpy as np
import os, glob
import shutil


df_total_list = pd.read_excel('class확정_20210707.xlsx', engine='openpyxl') # 엑셀 파일 로드
df_total_list = df_total_list.iloc[:,1:3].rename(columns={'라벨 인덱스':'class_number', 'FOOD_NM':'class_name'}) # 엑셀 컬럼 중 필요한 컬럼만 가져오기
df_total_list.dropna(inplace=True) # 널값 제거
df_total_list.class_number = df_total_list.class_number.astype(int) # class_number를 int로 변환

# %% [markdown]
# # 멀티레이블은 일단 안잡는다!

# %%
# class확정 엑셀 파일과 train,val폴더의 labels를 비교하는 함수
def check_data(dirs_name): # train, val 폴더들을 넣음.
    
    print(f'=========={dirs_name}==========')
    
    txt_classes = [] # txt 파일 안의 클래스를 담을 리스트.
    
    os.chdir(f'{dirs_name}/labels') # train, val 폴더안의 labels로 이동.
    des = os.getcwd()
    print(f'{dirs_name}/labels로 이동')
    files = os.listdir() # labels 폴더 내의 txt 파일들.
    print(f'{dirs_name}/labels 내의 txt 파일 개수: ', len(files))
#     print(files)
    
    
    empty_file = [] # 내용이 없는 file을 저장할 리스트
    
    for file in files: # for문으로 돌면서 txt 파일 하나씩 꺼냄.
        # txt 파일을 읽음.
        with open(file, "r") as f:
            text = f.read()
            # txt 파일 내용이 비어있을 경우, bin_txt 폴더에 'dirs_name이름_txt이름'으로 옮김.
            if text is "":
                empty_file.append(file)
                
###################### 빈 txt를 삭제하는 부분 #########################
###################### 처음에는 pass만 켜두고 #########################
######################## 실행해봐라!! #################################
#                 os.remove(f'{file}')
#                 if not os.path.exists('../../bin_txt'):
#                     os.makedirs('../../bin_txt')
#                 if not os.path.exists(f'../../bin_txt/{dirs_name}_bin_txt'):
#                     os.makedirs(f'../../bin_txt/{dirs_name}_bin_txt')
#                 os.chdir(f'../images')
#                 shutil.move(f'{file[:-3]}jpg', f'../../bin_txt/{dirs_name}_bin_txt')
#                 shutil.move(f'{file[:-3]}txt', f'../../bin_txt/{dirs_name}_bin_txt')
#                 os.chdir(f'../labels')
                pass
########################################################################


            # 내용이 있을 경우 정규표현식으로 내용의 첫 부분인 클래스만 추출
            else:
                p = re.compile(".*?\s")
                class_ = p.match(text).group()[:-1]
                # texts에 추출한 txt 저장
                txt_classes.append(class_)
    
    print('내용이 없는 txt 개수: ', len(empty_file))
    if len(empty_file) != 0:
        print(f'--{dirs_name}_bin_txt 폴더에 이동--')
    
    list_to_dict = {} # txt_classes의 '클래스_번호:개수'를 담을 딕셔너리
    
    # 내용이 있는 file들의 '클래스_번호:개수' 맵핑
    for text in txt_classes:
        if text in list_to_dict:
            list_to_dict[text] = list_to_dict[text]+1
        else:
            list_to_dict[text] = 1
    
    df = pd.DataFrame(list_to_dict.items(), columns=['class_number', 'counts']) # 딕셔너리를 데이터프레임으로 변환
    df.class_number = df.class_number.astype(int) # class_number를 int로 변환
    merge_df = pd.merge(df, df_total_list, on='class_number', how='left') # df_total_list와 병합
    merge_df = merge_df[['class_number', 'class_name', 'counts']] # 컬럼 순서 바꿈
    merge_df['folder'] = dirs_name # 폴더 이름 컬럼 추가
#     merge_df.to_excel(f'{dirs_name}.xlsx')


    # 폴더 안의 labels의 txt 파일들의 개수와 merge_df의 counts 개수가 일치하는지 확인!
    print(f'생성된 데이터프레임의 counts 개수: {len(files)}-{len(empty_file)} =', merge_df.counts.sum())
    if len(files)-len(empty_file) != merge_df.counts.sum():
        print('!!!!!!!!!!!!!!로드된 엑셀파일의 라벨 인덱스와 FOOD_NM에 이상이 있다!!!!!!!!!!')

    os.chdir(f'../..') # 현재 위치로 다시 이동
    print('\n')
    
    return merge_df



# check_data 함수실행 및 train_val 통합, 폴더 별로 엑셀 시트에 저장하는 함수

def execution():
    des = os.getcwd()
    des = des.split('/')[-1]
    print('현재 경로: ', des)
    print('')
    writer=pd.ExcelWriter(f'{des}.xlsx', engine='openpyxl')
    
    dirs = sorted(list(filter(os.path.isdir, glob.glob('*'))))
    train_list  = list(filter(lambda x: x.startswith('train'), dirs))
    val_list  = list(filter(lambda x: x.startswith('val'), dirs))
    train_val_list = train_list+val_list
    
    df_base= pd.DataFrame(columns=['class_number', 'class_name', 'counts'])
    
    for number, dir_ in enumerate(train_val_list):
        number = check_data(dir_)
        number = number[['class_number', 'class_name', 'counts']]
        number.to_excel(writer, sheet_name= f'{dir_}')
        df_base = pd.concat([df_base, number], axis=0, ignore_index=True)
        
    df_base.class_number = df_base.class_number.astype(int)
    df_base.counts = df_base.counts.astype(int)
    df_base = df_base.groupby('class_number').sum().reset_index()
    merge_df = pd.merge(df_base, df_total_list, on='class_number', how='left') # df_total_list와 병합
    merge_df = merge_df[['class_number', 'class_name', 'counts']] # 컬럼 순서 바꿈
    merge_df.to_excel(writer, sheet_name=f'train_val_total')
    writer.save()
    
    print('실행 완료')
    
    return merge_df

# %%
# !pwd
# Out:
# /data/FoodDetection/Object_Detection/yolov5-test/yolov5/dataset

# %%
# %cd ../../yolov5/dataset
# Out:
# /data/FoodDetection/Object_Detection/yolov5-test/yolov5/dataset

# %%
# 실행
df1 = execution()
df1
# Out:
# 현재 경로:  dataset
#
# ==========train1==========
# train1/labels로 이동
# train1/labels 내의 txt 파일 개수:  41924
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 41924-0 = 41924
#
#
# ==========train2==========
# train2/labels로 이동
# train2/labels 내의 txt 파일 개수:  89518
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 89518-0 = 89518
#
#
# ==========train3==========
# train3/labels로 이동
# train3/labels 내의 txt 파일 개수:  30675
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 30675-0 = 30675
#
#
# ==========train4==========
# train4/labels로 이동
# train4/labels 내의 txt 파일 개수:  3595
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 3595-0 = 3595
#
#
# ==========train5==========
# train5/labels로 이동
# train5/labels 내의 txt 파일 개수:  13188
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 13188-0 = 13188
#
#
# ==========train6==========
# train6/labels로 이동
# train6/labels 내의 txt 파일 개수:  3963
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 3963-0 = 3963
#
#
# ==========train7==========
# train7/labels로 이동
# train7/labels 내의 txt 파일 개수:  28507
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 28507-0 = 28507
#
#
# ==========train8==========
# train8/labels로 이동
# train8/labels 내의 txt 파일 개수:  35855
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 35855-0 = 35855
#
#
# ==========val1==========
# val1/labels로 이동
# val1/labels 내의 txt 파일 개수:  4696
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 4696-0 = 4696
#
#
# ==========val2==========
# val2/labels로 이동
# val2/labels 내의 txt 파일 개수:  10040
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 10040-0 = 10040
#
#
# ==========val3==========
# val3/labels로 이동
# val3/labels 내의 txt 파일 개수:  3466
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 3466-0 = 3466
#
#
# ==========val4==========
# val4/labels로 이동
# val4/labels 내의 txt 파일 개수:  420
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 420-0 = 420
#
#
# ==========val5==========
# val5/labels로 이동
# val5/labels 내의 txt 파일 개수:  1493
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 1493-0 = 1493
#
#
# ==========val6==========
# val6/labels로 이동
# val6/labels 내의 txt 파일 개수:  458
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 458-0 = 458
#
#
# ==========val7==========
# val7/labels로 이동
# val7/labels 내의 txt 파일 개수:  3249
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 3249-0 = 3249
#
#
# ==========val8==========
# val8/labels로 이동
# val8/labels 내의 txt 파일 개수:  3493
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 3493-0 = 3493
#
#
# 실행 완료
#      class_number class_name  counts
# 0               0      가리비구이     570
# 1               1      가자미구이     361
# 2               2      가자미조림     672
# 3               3       가지나물     801
# 4               4       가지냉국     595
# ..            ...        ...     ...
# 694           696     파래야채튀김     165
# 695           697      콩나물무침     156
# 696           698     소고기 구이     403
# 697           700         피자     773
# 698           718         자몽     184
#
# [699 rows x 3 columns]

# %%
# 실행
execution()
# Out:
# ==========train1==========
# train1/labels로 이동
# train1/labels 내의 txt 파일 개수:  41924
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 41924-0 = 41924
#
#
# ==========train2==========
# train2/labels로 이동
# train2/labels 내의 txt 파일 개수:  89518
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 89518-0 = 89518
#
#
# ==========train3==========
# train3/labels로 이동
# train3/labels 내의 txt 파일 개수:  30675
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 30675-0 = 30675
#
#
# ==========train4==========
# train4/labels로 이동
# train4/labels 내의 txt 파일 개수:  3595
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 3595-0 = 3595
#
#
# ==========train5==========
# train5/labels로 이동
# train5/labels 내의 txt 파일 개수:  13188
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 13188-0 = 13188
#
#
# ==========train6==========
# train6/labels로 이동
# train6/labels 내의 txt 파일 개수:  3963
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 3963-0 = 3963
#
#
# ==========train7==========
# train7/labels로 이동
# train7/labels 내의 txt 파일 개수:  28507
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 28507-0 = 28507
#
#
# ==========train8==========
# train8/labels로 이동
# train8/labels 내의 txt 파일 개수:  36109
# 내용이 없는 txt 개수:  254
# --train8_bin_txt 폴더에 이동--
# 생성된 데이터프레임의 counts 개수: 36109-254 = 35855
#
#
# ==========val1==========
# val1/labels로 이동
# val1/labels 내의 txt 파일 개수:  4696
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 4696-0 = 4696
#
#
# ==========val2==========
# val2/labels로 이동
# val2/labels 내의 txt 파일 개수:  10040
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 10040-0 = 10040
#
#
# ==========val3==========
# val3/labels로 이동
# val3/labels 내의 txt 파일 개수:  3466
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 3466-0 = 3466
#
#
# ==========val4==========
# val4/labels로 이동
# val4/labels 내의 txt 파일 개수:  420
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 420-0 = 420
#
#
# ==========val5==========
# val5/labels로 이동
# val5/labels 내의 txt 파일 개수:  1493
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 1493-0 = 1493
#
#
# ==========val6==========
# val6/labels로 이동
# val6/labels 내의 txt 파일 개수:  458
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 458-0 = 458
#
#
# ==========val7==========
# val7/labels로 이동
# val7/labels 내의 txt 파일 개수:  3249
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 3249-0 = 3249
#
#
# ==========val8==========
# val8/labels로 이동
# val8/labels 내의 txt 파일 개수:  3505
# 내용이 없는 txt 개수:  12
# --val8_bin_txt 폴더에 이동--
# 생성된 데이터프레임의 counts 개수: 3505-12 = 3493
#
#
# 실행 완료
#      class_number class_name  counts
# 0               0      가리비구이     570
# 1               1      가자미구이     361
# 2               2      가자미조림     672
# 3               3       가지나물     801
# 4               4       가지냉국     595
# ..            ...        ...     ...
# 694           696     파래야채튀김     165
# 695           697      콩나물무침     156
# 696           698     소고기 구이     403
# 697           700         피자     773
# 698           718         자몽     184
#
# [699 rows x 3 columns]

# %%
# !pwd
# Out:
# /data/FoodDetection/Object_Detection/yolov5-test/yolov5/dataset

# %% [markdown]
# /data/FoodDetection/Object_Detection/yolov5-test/dataset/N2A_8_train_val로 이동

# %%
# %cd ../../dataset/N2A_8_train_val
# Out:
# /data/FoodDetection/Object_Detection/yolov5-test/dataset/N2A_8_train_val

# %%
# 실행
df2 = execution()
df2
# Out:
# 현재 경로:  N2A_8_train_val
#
# ==========train_N2A_8==========
# train_N2A_8/labels로 이동
# train_N2A_8/labels 내의 txt 파일 개수:  6542
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 6542-0 = 6542
#
#
# ==========val_N2A_8==========
# val_N2A_8/labels로 이동
# val_N2A_8/labels 내의 txt 파일 개수:  729
# 내용이 없는 txt 개수:  0
# 생성된 데이터프레임의 counts 개수: 729-0 = 729
#
#
# 실행 완료
#     class_number      class_name  counts
# 0             20            곱창볶음      34
# 1             46             단무지       1
# 2             61          도토리묵무침       1
# 3             77             갈비탕       2
# 4             87             깍두기       1
# 5             94            더덕구이       1
# 6             97            된장찌개       1
# 7             98              라면       1
# 8             99             만두국     542
# 9            103            매생이국       4
# 10           108            멸치볶음       1
# 11           122             미역국       1
# 12           130            배추김치       3
# 13           166              양파       9
# 14           198          장어양념구이     589
# 15           214            총각김치       2
# 16           224            콩나물국       1
# 17           230             토마토       1
# 18           259              쌀밥       1
# 19           263              만두      11
# 20           288             수제비       5
# 21           292            잔치국수       3
# 22           294              잡채       1
# 23           298           주꾸미볶음       4
# 24           300             칼국수       5
# 25           314              약과       1
# 26           318          곰탕_설렁탕       9
# 27           382             두부탕      16
# 28           383              배추      13
# 29           385           소고기볶음       1
# 30           401          소고기장조림      16
# 31           415              쪽파       6
# 32           418             북어국      17
# 33           437              마늘      24
# 34           688             흑미밥       1
# 35           714            장어구이     356
# 36           715            장어덮밥      14
# 37           719           닭찜,찜닭     828
# 38           779          메추리알조림     961
# 39           780     부추, 산부추, 생것       6
# 40           801        계란(달걀)덮밥       1
# 41           810              떡국     354
# 42           811         계란(달걀)국     861
# 43           822            곱창구이     925
# 44           824             과메기     863
# 45           825            생선조림     771
# 46           829  계란(달걀), 난황, 생것       2

# %% [markdown]
# N2A_8_train_val에서 새로 추가된 클래스 확인

# %%
set(df2.class_name.to_list()) - set(df1.class_name.to_list())
# Out:
# {'계란(달걀), 난황, 생것',
#  '계란(달걀)국',
#  '계란(달걀)덮밥',
#  '곱창구이',
#  '과메기',
#  '닭찜,찜닭',
#  '떡국',
#  '메추리알조림',
#  '부추, 산부추, 생것',
#  '생선조림',
#  '장어구이',
#  '장어덮밥'}

# %%
total = pd.concat([df1, df2], ignore_index=True).groupby('class_number').sum()
total
# Out:
#               counts
# class_number
# 0                570
# 1                361
# 2                672
# 3                801
# 4                595
# ...              ...
# 811              861
# 822              925
# 824              863
# 825              771
# 829                2
#
# [711 rows x 1 columns]

# %%
merge_df = pd.merge(total, df_total_list, on='class_number', how='left') # df_total_list와 병합
merge_df = merge_df[['class_number', 'class_name', 'counts']] # 컬럼 순서 바꿈
merge_df
# Out:
#      class_number      class_name  counts
# 0               0           가리비구이     570
# 1               1           가자미구이     361
# 2               2           가자미조림     672
# 3               3            가지나물     801
# 4               4            가지냉국     595
# ..            ...             ...     ...
# 706           811         계란(달걀)국     861
# 707           822            곱창구이     925
# 708           824             과메기     863
# 709           825            생선조림     771
# 710           829  계란(달걀), 난황, 생것       2
#
# [711 rows x 3 columns]

# %%
merge_df[merge_df.class_name=='떡국']
# Out:
#      class_number class_name  counts
# 705           810         떡국     354

# %%
merge_df[merge_df.class_name.isnull()]
# Out:
#      class_number class_name  counts
# 63             63        NaN    1007
# 264           264        NaN     348
# 266           266        NaN     294
# 283           283        NaN     217
# 284           284        NaN     164
# 285           285        NaN     194
# 321           321        NaN     296
# 328           328        NaN     324
# 330           330        NaN     274

# %%
merge_df[merge_df.class_name.duplicated()]
# duplicated는 하나가 빠져서 나온다!
# Out:
#      class_number class_name  counts
# 264           264        NaN     348
# 266           266        NaN     294
# 283           283        NaN     217
# 284           284        NaN     164
# 285           285        NaN     194
# 321           321        NaN     296
# 328           328        NaN     324
# 330           330        NaN     274

# %%
# !pwd
# Out:
# /data/FoodDetection/Object_Detection/yolov5-test/dataset/N2A_8_train_val

# %%
merge_df.to_excel('dataset+N2A.xlsx')

# %% [markdown]
# # '/Data/FoodDetection/data/food_detection/음식인식2차' 경로

# %%
# %cd ..
# Out:
# /

# %%
# !ls
# Out:
# bin   data  etc   lib	 media	opt   root  sbin  sys  usr
# boot  dev   home  lib64  mnt	proc  run   srv   tmp  var

# %% [markdown]
# /data와 /Data는 만날 수가 없구나ㅠㅠ

# %% [markdown]
# # 떡국 이미지 10장 뽑아라!
#
# /data/FoodDetection/Object_Detection/yolov5-test/dataset/N2A_8_train_val/train_N2A_8/images
#
# 경로이다.

# %%
# %cd /data/FoodDetection/Object_Detection/yolov5-test/dataset/N2A_8_train_val/train_N2A_8/labels
# Out:
# /data/FoodDetection/Object_Detection/yolov5-test/dataset/N2A_8_train_val/train_N2A_8/labels

# %%
# !pwd
# Out:
# /data/FoodDetection/Object_Detection/yolov5-test/dataset/N2A_8_train_val/train_N2A_8/images

# %%
떡국들 = []

files = os.listdir()
for file in files:
    with open(file, "r") as f:
        text = f.read()
        print(file)
        print(text)
        p = re.compile(".*?\s")
        class_ = p.match(text).group()[:-1]
        print(class_)
        print('=============')
        if class_ == '810':
            떡국들.append(file)
            
print('떡국 txt: ', 떡국들)

current_path = './'
new_path = '../떡국_10장'
if not os.path.exists(new_path):
    os.mkdir(new_path)

os.chdir('../images/')

# 파일 복사해서 옮기기!
# https://ansan-survivor.tistory.com/917

files = os.listdir()
for file in files:
    for 떡국 in 떡국들:
        if file[:-3] ==  떡국[:-3]:
            shutil.copy(file, new_path)
            print('"{}" has been copied in new folder!'.format(file))
            
os.chdir('../labels/')
# Out:
# Img_003_0000.txt
# 822 0.505804 0.560000 0.951907 0.860000
#
# 822
# =============
# Img_003_0001.txt
# 822 0.540084 0.500000 0.683544 0.875000
#
# 822
# =============
# Img_003_0003.txt
# 20 0.500865 0.501250 0.998270 0.997500
#
# 20
# =============
# Img_003_0004.txt
# 20 0.501667 0.491250 0.996667 0.737500
#
# 20
# =============
# Img_003_0006.txt
# 822 0.471667 0.520000 0.743333 0.805000
#
# 822
# =============
# Img_003_0007.txt
# 822 0.452658 0.448750 0.327243 0.392500
#
# 822
# =============
# Img_003_0008.txt
# 822 0.367089 0.151250 0.616034 0.297500
#
# 822
# =============
# Img_003_0009.txt
# 822 0.439286 0.638750 0.846429 0.442500
#
# 822
# =============
# Img_003_0010.txt
# 822 0.325041 0.587500 0.487562 0.665000
# 780 0.686567 0.620000 0.285240 0.550000
#
# 822
# =============
# Img_003_0013.txt
# 822 0.562588 0.525000 0.483826 0.660000
#
# 822
# =============
# Img_003_0014.txt
# 822 0.549930 0.567500 0.812940 0.865000
#
# 822
# =============
# Img_003_0015.txt
# 822 0.501406 0.522500 0.552743 0.620000
#
# 822
# =============
# Img_003_0017.txt
# 822 0.476744 0.578750 0.578073 0.687500
#
# 822
# =============
# Img_003_0018.txt
# 822 0.488372 0.447500 0.149502 0.275000
#
# 822
# =============
# Img_003_0019.txt
# 822 0.497508 0.455000 0.184385 0.210000
#
# 822
# =============
# Img_003_0021.txt
# 822 0.462625 0.612500 0.632890 0.555000
#
# 822
# =============
# Img_003_0022.txt
# 822 0.491561 0.536250 0.696203 0.922500
#
# 822
# =============
# Img_003_0023.txt
# 822 0.290833 0.546250 0.445000 0.242500
#
# 822
# =============
# Img_003_0024.txt
# 822 0.494374 0.628750 0.513361 0.742500
#
# 822
# =============
# Img_003_0025.txt
# 822 0.177215 0.281250 0.351617 0.557500
# 822 0.524613 0.550000 0.461322 0.500000
# 822 0.882560 0.728750 0.234880 0.542500
#
# 822
# =============
# Img_003_0026.txt
# 822 0.407876 0.552500 0.360056 0.695000
#
# 822
# =============
# Img_003_0027.txt
# 822 0.502814 0.391250 0.476548 0.657500
#
# 822
# =============
# Img_003_0028.txt
# 822 0.664452 0.343750 0.461794 0.362500
#
# 822
# =============
# Img_003_0029.txt
# 822 0.490849 0.581250 0.435940 0.837500
# 166 0.454243 0.465000 0.316140 0.395000
# 428 0.754576 0.807500 0.211314 0.375000
#
# 822
# =============
# Img_003_0030.txt
# 822 0.616402 0.658750 0.714286 0.527500
#
# 822
# =============
# Img_003_0031.txt
# 822 0.567176 0.481250 0.847328 0.837500
#
# 822
# =============
# Img_003_0032.txt
# 822 0.217500 0.331250 0.431667 0.577500
#
# 822
# =============
# Img_003_0034.txt
# 822 0.640713 0.320000 0.654784 0.570000
# 428 0.625704 0.827500 0.455910 0.345000
#
# 822
# =============
# Img_003_0035.txt
# 822 0.474916 0.726250 0.588629 0.437500
#
# 822
# =============
# Img_003_0037.txt
# 822 0.510300 0.547500 0.941948 0.900000
# 780 0.495318 0.506250 0.357678 0.362500
#
# 822
# =============
# Img_003_0038.txt
# 822 0.536606 0.552500 0.617304 0.565000
#
# 822
# =============
# Img_003_0039.txt
# 822 0.474167 0.296250 0.685000 0.407500
#
# 822
# =============
# Img_003_0040.txt
# 822 0.491667 0.487500 0.980000 0.885000
# 769 0.355833 0.415000 0.178333 0.410000
# 717 0.600000 0.405000 0.283333 0.375000
#
# 822
# =============
# Img_003_0041.txt
# 822 0.493433 0.458750 0.420263 0.537500
# 780 0.804878 0.513750 0.243902 0.812500
#
# 822
# =============
# Img_003_0042.txt
# 822 0.514953 0.560000 0.719626 0.610000
# 166 0.582243 0.466250 0.263551 0.302500
# 166 0.278505 0.652500 0.224299 0.160000
#
# 822
# =============
# Img_003_0043.txt
# 166 0.412879 0.507500 0.424242 0.435000
# 822 0.795455 0.588750 0.352273 0.752500
# 822 0.389205 0.845000 0.395833 0.195000
# 822 0.504735 0.157500 0.702652 0.245000
# 428 0.151515 0.585000 0.253788 0.405000
#
# 166
# =============
# Img_003_0044.txt
# 822 0.557223 0.433750 0.431520 0.467500
# 780 0.804878 0.532500 0.303940 0.885000
# 437 0.255159 0.445000 0.191370 0.445000
#
# 822
# =============
# Img_003_0045.txt
# 822 0.483969 0.650000 0.793893 0.550000
#
# 822
# =============
# Img_003_0046.txt
# 822 0.317579 0.362500 0.446103 0.675000
# 437 0.581260 0.606250 0.207297 0.187500
# 166 0.608624 0.433750 0.099502 0.217500
# 428 0.752073 0.553750 0.137645 0.342500
# 166 0.850746 0.373750 0.145937 0.187500
#
# 822
# =============
# Img_003_0047.txt
# 822 0.761667 0.591250 0.440000 0.632500
# 166 0.676667 0.378750 0.260000 0.217500
# 166 0.472500 0.717500 0.291667 0.345000
#
# 822
# =============
# Img_003_0048.txt
# 822 0.388333 0.623750 0.580000 0.667500
# 166 0.254167 0.333750 0.455000 0.287500
# 166 0.203333 0.790000 0.263333 0.315000
#
# 822
# =============
# Img_003_0051.txt
# 822 0.611667 0.378750 0.456667 0.382500
# 822 0.785000 0.680000 0.210000 0.395000
# 166 0.431667 0.256250 0.453333 0.257500
# 166 0.625833 0.713750 0.225000 0.362500
#
# 822
# =============
# Img_003_0052.txt
# 822 0.153078 0.581250 0.302829 0.582500
# 166 0.252912 0.203750 0.502496 0.397500
# 437 0.495008 0.543750 0.520799 0.567500
#
# 822
# =============
# Img_003_0053.txt
# 822 0.518762 0.470000 0.887430 0.925000
# 166 0.249531 0.483750 0.311445 0.327500
#
# 822
# =============
# Img_003_0054.txt
# 822 0.413374 0.368750 0.398176 0.432500
#
# 822
# =============
# Img_003_0056.txt
# 822 0.429825 0.417500 0.567251 0.395000
# 780 0.397661 0.197500 0.520468 0.290000
#
# 822
# =============
# Img_003_0058.txt
# 822 0.492512 0.622500 0.552413 0.445000
# 166 0.500000 0.303750 0.477537 0.357500
# 705 0.088186 0.107500 0.173045 0.200000
#
# 822
# =============
# Img_003_0059.txt
# 822 0.488722 0.395000 0.471178 0.580000
#
# 822
# =============
# Img_003_0060.txt
# 822 0.584428 0.661250 0.699812 0.257500
# 822 0.832083 0.397500 0.189493 0.325000
# 780 0.493433 0.423750 0.544090 0.442500
#
# 822
# =============
# Img_003_0061.txt
# 780 0.455000 0.567500 0.370000 0.710000
# 822 0.783333 0.402500 0.413333 0.580000
# 822 0.168333 0.310000 0.333333 0.385000
#
# 780
# =============
# Img_003_0062.txt
# 822 0.600833 0.555000 0.645000 0.450000
#
# 822
# =============
# Img_003_0063.txt
# 822 0.448333 0.487500 0.893333 0.765000
#
# 822
# =============
# Img_003_0064.txt
# 822 0.258427 0.586250 0.292135 0.387500
# 822 0.797753 0.415000 0.382022 0.130000
# 822 0.664794 0.716250 0.670412 0.087500
#
# 822
# =============
# Img_003_0065.txt
# 822 0.527318 0.498750 0.428808 0.447500
# 166 0.210265 0.542500 0.215232 0.270000
#
# 822
# =============
# Img_003_0066.txt
# 822 0.532500 0.547500 0.455000 0.410000
#
# 822
# =============
# Img_003_0067.txt
# 822 0.520000 0.453750 0.396667 0.582500
# 780 0.783333 0.501250 0.156667 0.617500
# 769 0.589167 0.108750 0.228333 0.192500
#
# 822
# =============
# Img_003_0068.txt
# 822 0.722925 0.493750 0.213783 0.722500
# 822 0.546414 0.780000 0.620253 0.300000
# 822 0.244726 0.508750 0.149086 0.467500
# 780 0.455696 0.488750 0.312236 0.612500
#
# 822
# =============
# Img_003_0069.txt
# 822 0.567511 0.456250 0.676512 0.662500
#
# 822
# =============
# Img_003_0070.txt
# 822 0.498750 0.521250 0.807500 0.642500
#
# 822
# =============
# Img_003_0071.txt
# 822 0.525000 0.672500 0.630000 0.615000
# 166 0.156667 0.845000 0.300000 0.295000
# 770 0.106667 0.600000 0.210000 0.270000
#
# 822
# =============
# Img_003_0073.txt
# 822 0.519167 0.501250 0.771667 0.652500
#
# 822
# =============
# Img_003_0074.txt
# 822 0.506567 0.506250 0.964353 0.912500
#
# 822
# =============
# Img_003_0075.txt
# 822 0.480833 0.485000 0.378333 0.440000
# 780 0.227500 0.362500 0.335000 0.360000
#
# 822
# =============
# Img_003_0076.txt
# 822 0.520000 0.735000 0.603333 0.250000
# 822 0.479167 0.231250 0.451667 0.132500
# 822 0.246667 0.501250 0.136667 0.482500
#
# 822
# =============
# Img_003_0077.txt
# 822 0.559167 0.466250 0.511667 0.482500
#
# 822
# =============
# Img_003_0078.txt
# 822 0.533569 0.588750 0.590106 0.677500
#
# 822
# =============
# Img_003_0079.txt
# 822 0.543333 0.488750 0.493333 0.477500
#
# 822
# =============
# Img_003_0080.txt
# 822 0.497500 0.492500 0.991667 0.980000
#
# 822
# =============
# Img_003_0081.txt
# 822 0.394934 0.448750 0.786116 0.887500
# 780 0.810507 0.501250 0.375235 0.997500
#
# 822
# =============
# Img_003_0082.txt
# 822 0.515823 0.483750 0.718354 0.692500
#
# 822
# =============
# Img_003_0083.txt
# 822 0.531895 0.487500 0.621013 0.605000
#
# 822
# =============
# Img_003_0084.txt
# 822 0.500938 0.577500 0.998124 0.845000
#
# 822
# =============
# Img_003_0085.txt
# 822 0.531895 0.485000 0.673546 0.655000
#
# 822
# =============
# Img_003_0086.txt
# 822 0.718574 0.668750 0.562852 0.662500
#
# 822
# =============
# Img_003_0087.txt
# 822 0.496248 0.573750 0.504690 0.552500
# 166 0.518762 0.516250 0.268293 0.302500
#
# 822
# =============
# Img_003_0088.txt
# 822 0.530179 0.467500 0.900489 0.910000
#
# 822
# =============
# Img_003_0089.txt
# 822 0.574109 0.550000 0.675422 0.730000
#
# 822
# =============
# Img_003_0090.txt
# 822 0.613787 0.522500 0.483389 0.655000
# 166 0.333056 0.636250 0.403654 0.447500
#
# 822
# =============
# Img_003_0091.txt
# 822 0.557309 0.390000 0.317276 0.365000
# 166 0.632060 0.685000 0.237542 0.295000
#
# 822
# =============
# Img_003_0092.txt
# 822 0.471026 0.541250 0.670530 0.512500
#
# 822
# =============
# Img_003_0093.txt
# 822 0.814259 0.296250 0.367730 0.297500
# 822 0.412758 0.451250 0.243902 0.192500
#
# 822
# =============
# Img_003_0094.txt
# 822 0.481679 0.475000 0.941985 0.850000
#
# 822
# =============
# Img_003_0096.txt
# 822 0.527531 0.485000 0.781528 0.935000
#
# 822
# =============
# Img_003_0097.txt
# 822 0.506567 0.498750 0.645403 0.752500
#
# 822
# =============
# Img_003_0098.txt
# 822 0.525790 0.483750 0.948419 0.892500
#
# 822
# =============
# Img_003_0099.txt
# 20 0.514873 0.545000 0.766289 0.675000
#
# 20
# =============
# Img_003_0100.txt
# 20 0.510000 0.623750 0.790000 0.597500
#
# 20
# =============
# Img_003_0101.txt
# 822 0.551250 0.546250 0.477500 0.672500
# 780 0.227500 0.525000 0.225000 0.510000
#
# 822
# =============
# Img_003_0102.txt
# 822 0.515000 0.512500 0.700000 0.600000
# 437 0.516250 0.540000 0.072500 0.150000
# 166 0.370000 0.567500 0.145000 0.180000
#
# 822
# =============
# Img_003_0103.txt
# 20 0.333750 0.572500 0.662500 0.855000
#
# 20
# =============
# Img_003_0104.txt
# 822 0.547842 0.397500 0.585366 0.390000
# 780 0.400563 0.690000 0.452158 0.475000
#
# 822
# =============
# Img_003_0105.txt
# 822 0.553750 0.430000 0.817500 0.585000
# 166 0.383750 0.507500 0.192500 0.200000
# 437 0.577500 0.501250 0.110000 0.157500
#
# 822
# =============
# Img_003_0106.txt
# 20 0.502814 0.508750 0.776735 0.567500
#
# 20
# =============
# Img_003_0107.txt
# 822 0.765823 0.411250 0.403657 0.652500
# 822 0.243319 0.433750 0.194093 0.392500
# 166 0.394515 0.461250 0.167370 0.232500
# 437 0.529536 0.453750 0.082982 0.202500
#
# 822
# =============
# Img_003_0108.txt
# 822 0.511250 0.451250 0.257500 0.297500
# 822 0.558750 0.250000 0.432500 0.290000
#
# 822
# =============
# Img_003_0109.txt
# 822 0.481221 0.202500 0.671362 0.350000
# 822 0.244131 0.641250 0.413146 0.312500
#
# 822
# =============
# Img_003_0110.txt
# 822 0.723468 0.536250 0.269058 0.567500
# 780 0.508221 0.456250 0.221226 0.552500
# 437 0.588939 0.865000 0.077728 0.155000
#
# 822
# =============
# Img_003_0111.txt
# 822 0.552326 0.470000 0.852159 0.910000
# 166 0.120432 0.610000 0.234219 0.625000
#
# 822
# =============
# Img_003_0112.txt
# 822 0.613787 0.453750 0.702658 0.507500
#
# 822
# =============
# Img_003_0113.txt
# 822 0.566445 0.418750 0.867110 0.827500
#
# 822
# =============
# Img_003_0114.txt
# 822 0.524086 0.457500 0.772425 0.555000
# 166 0.392857 0.863750 0.782392 0.272500
#
# 822
# =============
# Img_003_0115.txt
# 822 0.840532 0.500000 0.318937 0.970000
# 166 0.520764 0.548750 0.363787 0.617500
#
# 822
# =============
# Img_003_0116.txt
# 166 0.189369 0.168750 0.282392 0.282500
# 822 0.598837 0.505000 0.553156 0.745000
#
# 166
# =============
# Img_003_0117.txt
# 822 0.596346 0.342500 0.807309 0.490000
# 166 0.806478 0.733750 0.387043 0.492500
#
# 822
# =============
# Img_003_0119.txt
# 822 0.252492 0.563750 0.498339 0.857500
# 822 0.680233 0.728750 0.387043 0.497500
#
# 822
# =============
# Img_003_0120.txt
# 822 0.882890 0.523750 0.234219 0.937500
# 166 0.341362 0.353750 0.307309 0.477500
# 166 0.637874 0.706250 0.328904 0.377500
#
# 822
# =============
# Img_003_0121.txt
# 822 0.639535 0.508750 0.710963 0.982500
#
# 822
# =============
# Img_003_0122.txt
# 822 0.612126 0.331250 0.543189 0.262500
# 822 0.818937 0.713750 0.362126 0.572500
#
# 822
# =============
# Img_003_0123.txt
# 822 0.392857 0.515000 0.373754 0.625000
#
# 822
# =============
# Img_003_0124.txt
# 822 0.496667 0.471250 0.610000 0.737500
# 780 0.480000 0.415000 0.336667 0.355000
#
# 822
# =============
# Img_003_0125.txt
# 822 0.466667 0.415000 0.893333 0.735000
#
# 822
# =============
# Img_003_0126.txt
# 822 0.348915 0.417500 0.397329 0.270000
# 780 0.725376 0.465000 0.315526 0.495000
# 437 0.487479 0.622500 0.126878 0.215000
#
# 822
# =============
# Img_003_0127.txt
# 780 0.291667 0.367500 0.370000 0.410000
# 822 0.605000 0.480000 0.323333 0.490000
# 166 0.365833 0.556250 0.175000 0.172500
#
# 780
# =============
# Img_003_0128.txt
# 822 0.528220 0.577500 0.535456 0.760000
# 166 0.842258 0.635000 0.312590 0.730000
#
# 822
# =============
# Img_003_0129.txt
# 822 0.434167 0.517500 0.335000 0.595000
#
# 822
# =============
# Img_003_0130.txt
# 822 0.509228 0.765000 0.961409 0.430000
#
# 822
# =============
# Img_003_0131.txt
# 822 0.495854 0.493750 0.759536 0.827500
#
# 822
# =============
# Img_003_0132.txt
# 822 0.488045 0.500000 0.843882 0.915000
#
# 822
# =============
# Img_003_0133.txt
# 822 0.465291 0.417500 0.375235 0.205000
# 437 0.473734 0.525000 0.076923 0.080000
#
# 822
# =============
# Img_003_0134.txt
# 822 0.511257 0.430000 0.523452 0.450000
# 437 0.530957 0.688750 0.108818 0.182500
#
# 822
# =============
# Img_003_0135.txt
# 822 0.508460 0.663750 0.776650 0.357500
# 822 0.855330 0.340000 0.191201 0.465000
# 822 0.181895 0.362500 0.201354 0.385000
# 166 0.445008 0.513750 0.267343 0.272500
# 780 0.543993 0.328750 0.370558 0.397500
#
# 822
# =============
# Img_003_0136.txt
# 822 0.513536 0.820000 0.668359 0.240000
# 780 0.637902 0.530000 0.216582 0.400000
#
# 822
# =============
# Img_003_0137.txt
# 822 0.488156 0.407500 0.187817 0.190000
# 822 0.478003 0.782500 0.712352 0.295000
#
# 822
# =============
# Img_003_0138.txt
# 822 0.484114 0.340000 0.610368 0.520000
#
# 822
# =============
# Img_003_0139.txt
# 822 0.472408 0.615000 0.506689 0.715000
#
# 822
# =============
# Img_003_0140.txt
# 822 0.649666 0.590000 0.700669 0.785000
#
# 822
# =============
# Img_003_0141.txt
# 822 0.547659 0.512500 0.560201 0.735000
#
# 822
# =============
# Img_003_0142.txt
# 822 0.484456 0.402500 0.963731 0.605000
#
# 822
# =============
# Img_003_0144.txt
# 822 0.481758 0.608750 0.900498 0.547500
#
# 822
# =============
# Img_003_0145.txt
# 822 0.474295 0.513750 0.577114 0.762500
# 822 0.875622 0.678750 0.248756 0.357500
# 780 0.834163 0.277500 0.321725 0.255000
#
# 822
# =============
# Img_003_0146.txt
# 822 0.489583 0.481250 0.892045 0.842500
#
# 822
# =============
# Img_003_0147.txt
# 822 0.528045 0.531250 0.729167 0.392500
#
# 822
# =============
# Img_003_0148.txt
# 822 0.575804 0.423750 0.814701 0.752500
# 437 0.084227 0.341250 0.131700 0.387500
# 437 0.210567 0.720000 0.209801 0.360000
# 437 0.320827 0.417500 0.127106 0.275000
#
# 822
# =============
# Img_003_0149.txt
# 822 0.740150 0.528750 0.463415 0.552500
#
# 822
# =============
# Img_003_0150.txt
# 822 0.780986 0.472500 0.438028 0.900000
# 822 0.281690 0.590000 0.515493 0.515000
# 437 0.404930 0.220000 0.254930 0.305000
#
# 822
# =============
# Img_003_0151.txt
# 822 0.321667 0.498750 0.623333 0.972500
#
# 822
# =============
# Img_003_0152.txt
# 822 0.584027 0.250000 0.595674 0.205000
# 822 0.853577 0.562500 0.186356 0.610000
# 822 0.648087 0.752500 0.324459 0.160000
#
# 822
# =============
# Img_003_0153.txt
# 822 0.484167 0.387500 0.535000 0.335000
#
# 822
# =============
# Img_003_0154.txt
# 822 0.552500 0.485000 0.408333 0.450000
#
# 822
# =============
# Img_003_0155.txt
# 822 0.365000 0.562500 0.413333 0.495000
# 697 0.923333 0.356250 0.150000 0.232500
# 166 0.528333 0.836250 0.163333 0.192500
# 697 0.162500 0.300000 0.208333 0.235000
#
# 822
# =============
# Img_003_0156.txt
# 822 0.693333 0.613750 0.606667 0.772500
#
# 822
# =============
# Img_003_0157.txt
# 822 0.383333 0.548750 0.483333 0.697500
# 166 0.937500 0.420000 0.125000 0.395000
#
# 822
# =============
# Img_003_0158.txt
# 822 0.385000 0.563750 0.323333 0.492500
# 697 0.161667 0.296250 0.196667 0.242500
# 697 0.913333 0.350000 0.163333 0.245000
#
# 822
# =============
# Img_003_0159.txt
# 822 0.592500 0.562500 0.488333 0.790000
#
# 822
# =============
# Img_003_0160.txt
# 822 0.514167 0.638750 0.561667 0.662500
# 822 0.769167 0.287500 0.305000 0.365000
#
# 822
# =============
# Img_003_0161.txt
# 822 0.254576 0.545000 0.372712 0.440000
# 822 0.764559 0.517500 0.440932 0.685000
# 437 0.496672 0.710000 0.168053 0.230000
#
# 822
# =============
# Img_003_0162.txt
# 822 0.251877 0.575000 0.213511 0.565000
# 822 0.746872 0.596250 0.192661 0.562500
#
# 822
# =============
# Img_003_0163.txt
# 822 0.270169 0.448750 0.307692 0.512500
# 166 0.071295 0.620000 0.138837 0.220000
#
# 822
# =============
# Img_003_0164.txt
# 822 0.817073 0.477500 0.365854 0.940000
# 166 0.322702 0.873750 0.363977 0.252500
# 822 0.470919 0.630000 0.213884 0.325000
#
# 822
# =============
# Img_003_0165.txt
# 822 0.570833 0.368750 0.558333 0.522500
# 166 0.645833 0.733750 0.238333 0.327500
# 780 0.199167 0.321250 0.241667 0.377500
#
# 822
# =============
# Img_003_0166.txt
# 822 0.552500 0.562500 0.441667 0.540000
#
# 822
# =============
# Img_003_0167.txt
# 822 0.809568 0.615000 0.365854 0.480000
# 822 0.313321 0.723750 0.615385 0.527500
# 822 0.605066 0.186250 0.200750 0.362500
#
# 822
# =============
# Img_003_0168.txt
# 822 0.706379 0.488750 0.193246 0.552500
#
# 822
# =============
# Img_003_0169.txt
# 822 0.493367 0.508750 0.893864 0.542500
# 822 0.189884 0.715000 0.376451 0.570000
#
# 822
# =============
# Img_003_0170.txt
# 822 0.507022 0.292500 0.441011 0.415000
# 166 0.761938 0.563750 0.327247 0.592500
# 437 0.544944 0.833750 0.213483 0.182500
#
# 822
# =============
# Img_003_0171.txt
# 822 0.545966 0.540000 0.450281 0.610000
#
# 822
# =============
# Img_003_0172.txt
# 822 0.572233 0.446250 0.848030 0.862500
#
# 822
# =============
# Img_003_0173.txt
# 822 0.474672 0.472500 0.697936 0.615000
#
# 822
# =============
# Img_003_0174.txt
# 822 0.454034 0.496250 0.465291 0.547500
#
# 822
# =============
# Img_003_0176.txt
# 822 0.400563 0.513750 0.568480 0.497500
# 166 0.779550 0.667500 0.365854 0.640000
# 780 0.330206 0.866250 0.510319 0.247500
#
# 822
# =============
# Img_003_0178.txt
# 822 0.577068 0.555000 0.823308 0.650000
#
# 822
# =============
# Img_003_0179.txt
# 822 0.432500 0.498750 0.401667 0.757500
#
# 822
# =============
# Img_003_0180.txt
# 822 0.459581 0.443750 0.389222 0.332500
# 166 0.500000 0.628750 0.146707 0.177500
# 166 0.715569 0.370000 0.164671 0.220000
#
# 822
# =============
# Img_003_0181.txt
# 822 0.587671 0.748750 0.495890 0.312500
# 780 0.198630 0.676250 0.282192 0.157500
# 437 0.498630 0.678750 0.169863 0.097500
#
# 822
# =============
# Img_003_0182.txt
# 822 0.493371 0.457500 0.922348 0.855000
#
# 822
# =============
# Img_003_0184.txt
# 822 0.512500 0.516250 0.651667 0.767500
#
# 822
# =============
# Img_003_0185.txt
# 822 0.679325 0.455000 0.587904 0.865000
#
# 822
# =============
# Img_003_0186.txt
# 822 0.526266 0.423750 0.879925 0.712500
#
# 822
# =============
# Img_003_0187.txt
# 822 0.439167 0.553750 0.781667 0.692500
# 166 0.744167 0.270000 0.185000 0.285000
#
# 822
# =============
# Img_003_0188.txt
# 822 0.484167 0.532500 0.598333 0.625000
#
# 822
# =============
# Img_003_0189.txt
# 822 0.349167 0.431250 0.661667 0.772500
#
# 822
# =============
# Img_003_0190.txt
# 822 0.443333 0.458750 0.650000 0.582500
#
# 822
# =============
# Img_003_0191.txt
# 822 0.488333 0.606250 0.583333 0.427500
#
# 822
# =============
# Img_003_0192.txt
# 822 0.220833 0.522500 0.345000 0.445000
#
# 822
# =============
# Img_003_0193.txt
# 822 0.502019 0.688750 0.995962 0.622500
# 822 0.513459 0.245000 0.235532 0.440000
#
# 822
# =============
# Img_003_0194.txt
# 822 0.501346 0.502500 0.997308 0.995000
#
# 822
# =============
# Img_003_0196.txt
# 822 0.453333 0.501250 0.903333 0.997500
#
# 822
# =============
# Img_003_0197.txt
# 822 0.500673 0.503750 0.998654 0.992500
#
# 822
# =============
# Img_003_0198.txt
# 822 0.500673 0.501250 0.998654 0.987500
#
# 822
# =============
# Img_003_0199.txt
# 822 0.500833 0.502500 0.998333 0.995000
#
# 822
# =============
# Img_003_0200.txt
# 822 0.377524 0.308750 0.526245 0.422500
# 822 0.653432 0.698750 0.690444 0.587500
# 166 0.208614 0.748750 0.409152 0.502500
#
# 822
# =============
# Img_003_0201.txt
# 822 0.423284 0.302500 0.585464 0.455000
# 822 0.663526 0.733750 0.672948 0.532500
# 166 0.205249 0.758750 0.405114 0.482500
#
# 822
# =============
# Img_003_0202.txt
# 822 0.465833 0.503750 0.921667 0.992500
#
# 822
# =============
# Img_003_0203.txt
# 822 0.505000 0.510000 0.990000 0.980000
#
# 822
# =============
# Img_003_0204.txt
# 822 0.462988 0.501250 0.920592 0.997500
#
# 822
# =============
# Img_003_0205.txt
# 822 0.502019 0.303750 0.995962 0.592500
# 166 0.521534 0.777500 0.534320 0.445000
#
# 822
# =============
# Img_003_0206.txt
# 822 0.661667 0.525000 0.676667 0.950000
# 166 0.178333 0.571250 0.353333 0.452500
#
# 822
# =============
# Img_003_0207.txt
# 822 0.429341 0.483750 0.393001 0.712500
#
# 822
# =============
# Img_003_0208.txt
# 822 0.567295 0.847500 0.343203 0.305000
# 166 0.351952 0.792500 0.103634 0.415000
#
# 822
# =============
# Img_003_0209.txt
# 822 0.689098 0.503750 0.621803 0.992500
# 822 0.207268 0.746250 0.411844 0.507500
# 166 0.195828 0.363750 0.388964 0.392500
#
# 822
# =============
# Img_003_0210.txt
# 822 0.691370 0.545000 0.617261 0.910000
#
# 822
# =============
# Img_003_0211.txt
# 822 0.468105 0.641250 0.564728 0.412500
#
# 822
# =============
# Img_003_0212.txt
# 822 0.500703 0.536250 0.655415 0.927500
#
# 822
# =============
# Img_003_0213.txt
# 822 0.475000 0.487500 0.906667 0.720000
#
# 822
# =============
# Img_003_0214.txt
# 822 0.537523 0.521250 0.883677 0.957500
#
# 822
# =============
# Img_003_0215.txt
# 822 0.190833 0.225000 0.255000 0.240000
# 822 0.558333 0.545000 0.366667 0.375000
# 166 0.380833 0.180000 0.111667 0.125000
# 166 0.795833 0.521250 0.131667 0.167500
#
# 822
# =============
# Img_003_0216.txt
# 822 0.516667 0.555000 0.863333 0.425000
#
# 822
# =============
# Img_003_0217.txt
# 822 0.454993 0.492500 0.561181 0.640000
#
# 822
# =============
# Img_003_0219.txt
# 822 0.453586 0.448750 0.445851 0.557500
#
# 822
# =============
# Img_003_0220.txt
# 822 0.500703 0.358750 0.191280 0.252500
# 780 0.208861 0.770000 0.144866 0.200000
#
# 822
# =============
# Img_003_0221.txt
# 822 0.502488 0.503750 0.995025 0.992500
#
# 822
# =============
# Img_003_0222.txt
# 822 0.391667 0.528750 0.740000 0.942500
# 780 0.888333 0.668750 0.223333 0.662500
#
# 822
# =============
# Img_003_0223.txt
# 822 0.501876 0.491250 0.602251 0.517500
# 437 0.230769 0.223750 0.131332 0.102500
#
# 822
# =============
# Img_003_0224.txt
# 822 0.455980 0.493750 0.712625 0.787500
# 769 0.456811 0.422500 0.355482 0.315000
#
# 822
# =============
# Img_003_0225.txt
# 822 0.266667 0.532500 0.233333 0.715000
# 166 0.622500 0.341250 0.181667 0.192500
# 166 0.572500 0.530000 0.128333 0.175000
# 437 0.550833 0.443750 0.121667 0.112500
#
# 822
# =============
# Img_003_0226.txt
# 822 0.468443 0.533750 0.597475 0.847500
#
# 822
# =============
# Img_003_0227.txt
# 822 0.506567 0.531250 0.874296 0.817500
#
# 822
# =============
# Img_003_0228.txt
# 822 0.925562 0.462500 0.148876 0.420000
# 166 0.759129 0.493750 0.169944 0.207500
#
# 822
# =============
# Img_003_0229.txt
# 822 0.431882 0.410000 0.448034 0.665000
# 780 0.750000 0.273750 0.168539 0.367500
#
# 822
# =============
# Img_003_0230.txt
# 822 0.530197 0.422500 0.414326 0.540000
#
# 822
# =============
# Img_003_0231.txt
# 822 0.304878 0.717500 0.121951 0.225000
# 822 0.709193 0.662500 0.127580 0.365000
# 822 0.327392 0.263750 0.170732 0.182500
# 437 0.471857 0.462500 0.140713 0.120000
#
# 822
# =============
# Img_003_0233.txt
# 822 0.494371 0.395000 0.718574 0.645000
#
# 822
# =============
# Img_003_0234.txt
# 822 0.599156 0.405000 0.613221 0.535000
#
# 822
# =============
# Img_003_0235.txt
# 822 0.520833 0.510000 0.940217 0.965000
# 166 0.129529 0.291250 0.226449 0.392500
# 166 0.649457 0.232500 0.295290 0.215000
#
# 822
# =============
# Img_003_0237.txt
# 822 0.485929 0.331250 0.604128 0.432500
# 166 0.729831 0.663750 0.315197 0.282500
# 166 0.863039 0.357500 0.183865 0.430000
#
# 822
# =============
# Img_003_0238.txt
# 822 0.498124 0.428750 0.714822 0.652500
# 166 0.893996 0.615000 0.178236 0.395000
#
# 822
# =============
# Img_003_0240.txt
# 822 0.512458 0.517500 0.539867 0.445000
#
# 822
# =============
# Img_003_0242.txt
# 822 0.520240 0.486250 0.512744 0.817500
#
# 822
# =============
# Img_003_0243.txt
# 822 0.602251 0.298750 0.431520 0.527500
# 822 0.757974 0.432500 0.461538 0.280000
#
# 822
# =============
# Img_003_0244.txt
# 822 0.694068 0.527500 0.191525 0.560000
# 822 0.302542 0.696250 0.174576 0.262500
# 166 0.475424 0.617500 0.225424 0.300000
# 780 0.458475 0.281250 0.266102 0.282500
#
# 822
# =============
# Img_003_0245.txt
# 822 0.849167 0.692500 0.301667 0.270000
# 780 0.807500 0.320000 0.275000 0.365000
#
# 822
# =============
# Img_003_0246.txt
# 822 0.540000 0.602500 0.600000 0.365000
#
# 822
# =============
# Img_003_0247.txt
# 822 0.491708 0.523750 0.923715 0.892500
#
# 822
# =============
# Img_003_0248.txt
# 822 0.485929 0.521250 0.547842 0.627500
#
# 822
# =============
# Img_003_0249.txt
# 822 0.460674 0.473750 0.704120 0.362500
#
# 822
# =============
# Img_003_0250.txt
# 822 0.486667 0.462500 0.303333 0.335000
#
# 822
# =============
# Img_003_0251.txt
# 822 0.386492 0.461250 0.660413 0.617500
#
# 822
# =============
# Img_003_0252.txt
# 822 0.579737 0.522500 0.634146 0.600000
# 166 0.500000 0.451250 0.347092 0.307500
#
# 822
# =============
# Img_003_0253.txt
# 822 0.519934 0.483750 0.146179 0.192500
#
# 822
# =============
# Img_003_0254.txt
# 822 0.390000 0.598750 0.776667 0.582500
#
# 822
# =============
# Img_003_0255.txt
# 822 0.536545 0.427500 0.877076 0.795000
#
# 822
# =============
# Img_003_0256.txt
# 822 0.480929 0.500000 0.822554 0.855000
#
# 822
# =============
# Img_003_0257.txt
# 822 0.475124 0.517500 0.817579 0.835000
#
# 822
# =============
# Img_003_0258.txt
# 822 0.495077 0.577500 0.601969 0.830000
#
# 822
# =============
# Img_003_0259.txt
# 822 0.389718 0.491250 0.776119 0.972500
#
# 822
# =============
# Img_003_0260.txt
# 822 0.394343 0.456250 0.785358 0.487500
#
# 822
# =============
# Img_003_0261.txt
# 822 0.503752 0.507500 0.992495 0.985000
#
# 822
# =============
# Img_003_0262.txt
# 822 0.353390 0.476250 0.435593 0.292500
# 166 0.284746 0.468750 0.149153 0.142500
#
# 822
# =============
# Img_003_0264.txt
# 822 0.503322 0.508750 0.179402 0.262500
# 166 0.579734 0.803750 0.518272 0.392500
#
# 822
# =============
# Img_003_0265.txt
# 822 0.404167 0.525000 0.755000 0.365000
# 822 0.788333 0.233750 0.340000 0.462500
#
# 822
# =============
# Img_003_0266.txt
# 822 0.558626 0.581250 0.631491 0.532500
#
# 822
# =============
# Img_003_0267.txt
# 822 0.430478 0.452500 0.585674 0.855000
# 437 0.889045 0.566250 0.129213 0.232500
#
# 822
# =============
# Img_003_0268.txt
# 822 0.486891 0.472500 0.400749 0.550000
#
# 822
# =============
# Img_003_0269.txt
# 822 0.452736 0.435000 0.514096 0.380000
# 166 0.364842 0.208750 0.222222 0.172500
#
# 822
# =============
# Img_003_0271.txt
# 822 0.537313 0.478750 0.348259 0.492500
# 166 0.326700 0.393750 0.152570 0.382500
#
# 822
# =============
# Img_003_0272.txt
# 822 0.525833 0.562500 0.818333 0.875000
#
# 822
# =============
# Img_003_0273.txt
# 822 0.620000 0.567500 0.196667 0.230000
#
# 822
# =============
# Img_003_0275.txt
# 822 0.348333 0.580000 0.473333 0.425000
# 822 0.775833 0.386250 0.168333 0.532500
# 780 0.504167 0.322500 0.438333 0.575000
#
# 822
# =============
# Img_003_0276.txt
# 822 0.518303 0.497500 0.753744 0.935000
#
# 822
# =============
# Img_003_0277.txt
# 822 0.503328 0.511250 0.993344 0.977500
# 780 0.385191 0.507500 0.404326 0.645000
#
# 822
# =============
# Img_003_0278.txt
# 822 0.378049 0.525000 0.733583 0.625000
# 166 0.164165 0.391250 0.324578 0.262500
#
# 822
# =============
# Img_003_0279.txt
# 822 0.645403 0.463750 0.285178 0.507500
#
# 822
# =============
# Img_003_0280.txt
# 822 0.488411 0.555000 0.645695 0.575000
# 166 0.669702 0.160000 0.187086 0.205000
#
# 822
# =============
# Img_003_0281.txt
# 822 0.530000 0.560000 0.893333 0.240000
# 780 0.512500 0.393750 0.341667 0.322500
#
# 822
# =============
# Img_003_0283.txt
# 822 0.486667 0.502500 0.620000 0.895000
#
# 822
# =============
# Img_003_0284.txt
# 822 0.395000 0.517500 0.780000 0.580000
#
# 822
# =============
# Img_003_0285.txt
# 822 0.422881 0.521250 0.462712 0.817500
# 166 0.738136 0.538750 0.228814 0.317500
#
# 822
# =============
# Img_003_0286.txt
# 822 0.514190 0.478750 0.247078 0.367500
#
# 822
# =============
# Img_003_0287.txt
# 822 0.569167 0.430000 0.861667 0.815000
#
# 822
# =============
# Img_003_0288.txt
# 822 0.519167 0.618750 0.961667 0.762500
#
# 822
# =============
# Img_003_0289.txt
# 822 0.714407 0.630000 0.561017 0.660000
# 780 0.393220 0.606250 0.318644 0.322500
#
# 822
# =============
# Img_003_0290.txt
# 822 0.590000 0.682500 0.783333 0.420000
# 780 0.533333 0.470000 0.180000 0.180000
#
# 822
# =============
# Img_003_0291.txt
# 822 0.541667 0.565000 0.810000 0.560000
# 166 0.702500 0.211250 0.338333 0.172500
#
# 822
# =============
# Img_003_0292.txt
# 822 0.535833 0.508750 0.638333 0.982500
#
# 822
# =============
# Img_003_0293.txt
# 822 0.565000 0.225000 0.813333 0.290000
#
# 822
# =============
# Img_003_0294.txt
# 822 0.299250 0.255000 0.159475 0.305000
# 780 0.803940 0.761250 0.208255 0.432500
#
# 822
# =============
# Img_003_0295.txt
# 822 0.501416 0.336250 0.331445 0.357500
# 780 0.493626 0.323750 0.174221 0.167500
# 780 0.849150 0.270000 0.168555 0.205000
#
# 822
# =============
# Img_003_0296.txt
# 822 0.504160 0.503750 0.991681 0.987500
# 437 0.176373 0.383750 0.153078 0.297500
# 166 0.462562 0.600000 0.262895 0.290000
#
# 822
# =============
# Img_003_0298.txt
# 822 0.421941 0.473750 0.461322 0.842500
#
# 822
# =============
# Img_003_0299.txt
# 822 0.514065 0.483750 0.558368 0.847500
#
# 822
# =============
# Img_003_0300.txt
# 822 0.487500 0.275000 0.195000 0.190000
# 822 0.800833 0.722500 0.391667 0.545000
#
# 822
# =============
# Img_003_0301.txt
# 822 0.660535 0.651250 0.672241 0.492500
#
# 822
# =============
# Img_003_0302.txt
# 822 0.485000 0.335000 0.350000 0.220000
#
# 822
# =============
# Img_003_0305.txt
# 822 0.387069 0.498750 0.674138 0.867500
#
# 822
# =============
# Img_003_0306.txt
# 822 0.373134 0.510000 0.610282 0.980000
#
# 822
# =============
# Img_003_0308.txt
# 822 0.581614 0.413750 0.821764 0.732500
# 166 0.569418 0.252500 0.373358 0.355000
#
# 822
# =============
# Img_003_0309.txt
# 822 0.320339 0.708750 0.600000 0.427500
# 822 0.610169 0.503750 0.193220 0.397500
#
# 822
# =============
# Img_003_0311.txt
# 822 0.533333 0.360000 0.316667 0.340000
# 166 0.254167 0.438750 0.288333 0.267500
#
# 822
# =============
# Img_003_0312.txt
# 822 0.532349 0.478750 0.935302 0.952500
#
# 822
# =============
# Img_003_0313.txt
# 822 0.198874 0.151250 0.296435 0.222500
# 822 0.566604 0.665000 0.225141 0.230000
# 166 0.794559 0.587500 0.350844 0.155000
#
# 822
# =============
# Img_003_0314.txt
# 822 0.490619 0.382500 0.587242 0.460000
# 166 0.269231 0.718750 0.463415 0.272500
#
# 822
# =============
# Img_003_0315.txt
# 822 0.435000 0.485000 0.616667 0.330000
#
# 822
# =============
# Img_003_0316.txt
# 822 0.500936 0.531250 0.979401 0.832500
#
# 822
# =============
# Img_003_0318.txt
# 822 0.620000 0.431250 0.706667 0.302500
#
# 822
# =============
# Img_003_0319.txt
# 822 0.501873 0.530000 0.992509 0.940000
#
# 822
# =============
# Img_003_0321.txt
# 822 0.615000 0.370000 0.710000 0.705000
# 166 0.208333 0.263750 0.310000 0.482500
# 166 0.848333 0.442500 0.303333 0.335000
#
# 822
# =============
# Img_003_0322.txt
# 822 0.517824 0.531250 0.863039 0.897500
#
# 822
# =============
# Img_003_0324.txt
# 822 0.322500 0.225000 0.451667 0.430000
# 166 0.089167 0.345000 0.175000 0.565000
#
# 822
# =============
# Img_003_0326.txt
# 822 0.554167 0.546250 0.711667 0.692500
# 166 0.108333 0.381250 0.213333 0.212500
#
# 822
# =============
# Img_003_0327.txt
# 822 0.574213 0.468750 0.566717 0.712500
# 780 0.317841 0.791250 0.380810 0.417500
#
# 822
# =============
# Img_003_0328.txt
# 822 0.426667 0.752500 0.360000 0.285000
# 822 0.615000 0.337500 0.273333 0.220000
# 166 0.547500 0.515000 0.331667 0.230000
#
# 822
# =============
# Img_003_0329.txt
# 822 0.518254 0.505000 0.668254 0.795000
#
# 822
# =============
# Img_003_0330.txt
# 822 0.439962 0.423750 0.609756 0.592500
#
# 822
# =============
# Img_003_0331.txt
# 822 0.545910 0.286250 0.267112 0.292500
# 780 0.262938 0.542500 0.181970 0.490000
#
# 822
# =============
# Img_003_0332.txt
# 822 0.530000 0.435000 0.883333 0.665000
#
# 822
# =============
# Img_003_0333.txt
# 822 0.516886 0.503750 0.966229 0.952500
#
# 822
# =============
# Img_003_0334.txt
# 822 0.608985 0.383750 0.469218 0.612500
# 166 0.492512 0.632500 0.449251 0.490000
#
# 822
# =============
# Img_003_0335.txt
# 822 0.444444 0.526250 0.457711 0.577500
# 822 0.290216 0.881250 0.560531 0.212500
#
# 822
# =============
# Img_003_0336.txt
# 822 0.477612 0.448750 0.686567 0.702500
# 166 0.565506 0.352500 0.248756 0.345000
#
# 822
# =============
# Img_003_0337.txt
# 822 0.613333 0.562500 0.530000 0.765000
# 166 0.921667 0.665000 0.156667 0.380000
# 780 0.269167 0.772500 0.205000 0.260000
#
# 822
# =============
# Img_003_0338.txt
# 822 0.511609 0.652500 0.704809 0.395000
#
# 822
# =============
# Img_003_0340.txt
# 822 0.350166 0.511250 0.322848 0.227500
# 166 0.579470 0.463750 0.162252 0.172500
#
# 822
# =============
# Img_003_0341.txt
# 822 0.623539 0.826250 0.462437 0.347500
#
# 822
# =============
# Img_003_0343.txt
# 822 0.403377 0.455000 0.517824 0.435000
# 780 0.849906 0.601250 0.266417 0.502500
# 166 0.290807 0.215000 0.315197 0.180000
#
# 822
# =============
# Img_003_0344.txt
# 822 0.285714 0.451250 0.106312 0.777500
# 822 0.761628 0.301250 0.078073 0.522500
# 822 0.533223 0.267500 0.066445 0.485000
# 780 0.404485 0.442500 0.167774 0.645000
# 780 0.642027 0.432500 0.131229 0.775000
#
# 822
# =============
# Img_003_0345.txt
# 822 0.381667 0.136250 0.330000 0.237500
# 822 0.135833 0.408750 0.248333 0.467500
# 166 0.277500 0.543750 0.148333 0.197500
# 437 0.277500 0.417500 0.105000 0.095000
# 233 0.665833 0.552500 0.325000 0.425000
# 780 0.483333 0.397500 0.310000 0.405000
#
# 822
# =============
# Img_003_0346.txt
# 822 0.471524 0.522500 0.296482 0.440000
#
# 822
# =============
# Img_003_0347.txt
# 822 0.525328 0.285000 0.776735 0.410000
# 780 0.733583 0.748750 0.532833 0.502500
#
# 822
# =============
# Img_003_0350.txt
# 822 0.390000 0.352500 0.625000 0.460000
#
# 822
# =============
# Img_003_0351.txt
# 822 0.515947 0.532500 0.637899 0.935000
#
# 822
# =============
# Img_003_0352.txt
# 822 0.539232 0.588750 0.310518 0.397500
# 780 0.353088 0.736250 0.268781 0.252500
# 166 0.731219 0.525000 0.096828 0.345000
#
# 822
# =============
# Img_003_0353.txt
# 822 0.511257 0.122500 0.834897 0.235000
# 822 0.606004 0.635000 0.679174 0.495000
# 166 0.298311 0.372500 0.521576 0.350000
#
# 822
# =============
# Img_003_0355.txt
# 822 0.517824 0.366250 0.934334 0.652500
#
# 822
# =============
# Img_003_0356.txt
# 822 0.563790 0.447500 0.756098 0.515000
# 166 0.711069 0.123750 0.360225 0.237500
#
# 822
# =============
# Img_003_0357.txt
# 822 0.606942 0.498750 0.594747 0.647500
# 166 0.574109 0.408750 0.127580 0.207500
# 437 0.462477 0.596250 0.118199 0.082500
#
# 822
# =============
# Img_003_0358.txt
# 822 0.501876 0.110000 0.771107 0.210000
# 822 0.593809 0.612500 0.658537 0.485000
# 166 0.309568 0.327500 0.529081 0.375000
# 437 0.657598 0.318750 0.136961 0.157500
#
# 822
# =============
# Img_003_0359.txt
# 822 0.487562 0.452500 0.945274 0.850000
# 780 0.417081 0.437500 0.439469 0.410000
# 437 0.800995 0.335000 0.135987 0.260000
#
# 822
# =============
# Img_003_0360.txt
# 822 0.608514 0.628750 0.492487 0.742500
#
# 822
# =============
# Img_003_0361.txt
# 822 0.445923 0.305000 0.239601 0.315000
#
# 822
# =============
# Img_003_0362.txt
# 822 0.541250 0.428750 0.772500 0.362500
# 166 0.335000 0.911250 0.325000 0.177500
#
# 822
# =============
# Img_003_0364.txt
# 822 0.524126 0.503750 0.951747 0.992500
#
# 822
# =============
# Img_003_0365.txt
# 822 0.512542 0.441250 0.867893 0.792500
#
# 822
# =============
# Img_003_0367.txt
# 822 0.620075 0.265000 0.354597 0.330000
# 822 0.292683 0.348750 0.210131 0.412500
# 166 0.507505 0.375000 0.302064 0.215000
# 780 0.605066 0.646250 0.339587 0.372500
#
# 822
# =============
# Img_003_0369.txt
# 829 0.602990 0.401250 0.601329 0.297500
# 166 0.742525 0.161250 0.232558 0.202500
#
# 829
# =============
# Img_003_0370.txt
# 822 0.499297 0.626250 0.599156 0.487500
# 437 0.208158 0.596250 0.087201 0.327500
#
# 822
# =============
# Img_003_0371.txt
# 822 0.526534 0.458750 0.834163 0.727500
#
# 822
# =============
# Img_003_0372.txt
# 822 0.514071 0.570000 0.971857 0.435000
#
# 822
# =============
# Img_003_0373.txt
# 822 0.623539 0.625000 0.752922 0.750000
#
# 822
# =============
# Img_003_0374.txt
# 822 0.684474 0.590000 0.631052 0.775000
#
# 822
# =============
# Img_003_0375.txt
# 822 0.665103 0.491250 0.669794 0.537500
#
# 822
# =============
# Img_003_0376.txt
# 822 0.504237 0.337500 0.723729 0.400000
# 822 0.371186 0.747500 0.450847 0.450000
# 166 0.659322 0.728750 0.274576 0.342500
#
# 822
# =============
# Img_003_0377.txt
# 822 0.468105 0.500000 0.485929 0.400000
#
# 822
# =============
# Img_003_0378.txt
# 822 0.607500 0.558750 0.315000 0.437500
# 780 0.347500 0.610000 0.375000 0.240000
#
# 822
# =============
# Img_003_0379.txt
# 20 0.479167 0.580000 0.631667 0.705000
# 769 0.110833 0.581250 0.211667 0.407500
# 769 0.635833 0.896250 0.385000 0.207500
# 769 0.828333 0.468750 0.243333 0.347500
#
# 20
# =============
# Img_003_0380.txt
# 822 0.497512 0.465000 0.769486 0.905000
#
# 822
# =============
# Img_003_0381.txt
# 822 0.280488 0.415000 0.557223 0.735000
# 166 0.559099 0.795000 0.814259 0.410000
#
# 822
# =============
# Img_003_0382.txt
# 822 0.483750 0.493750 0.807500 0.577500
# 166 0.361250 0.140000 0.437500 0.105000
# 437 0.918750 0.696250 0.157500 0.252500
#
# 822
# =============
# Img_003_0383.txt
# 822 0.508443 0.443750 0.454034 0.307500
# 166 0.241088 0.536250 0.148218 0.217500
#
# 822
# =============
# Img_003_0384.txt
# 822 0.609817 0.382500 0.514143 0.480000
# 166 0.405158 0.110000 0.387687 0.150000
# 166 0.232945 0.427500 0.149750 0.280000
# 166 0.604825 0.735000 0.271215 0.325000
#
# 822
# =============
# Img_003_0387.txt
# 822 0.433396 0.490000 0.476548 0.645000
#
# 822
# =============
# Img_003_0388.txt
# 822 0.449367 0.487500 0.527426 0.700000
# 166 0.389592 0.500000 0.292546 0.450000
#
# 822
# =============
# Img_003_0389.txt
# 822 0.464724 0.547500 0.475460 0.465000
# 166 0.292945 0.216250 0.352761 0.352500
# 166 0.822086 0.417500 0.325153 0.270000
#
# 822
# =============
# Img_003_0390.txt
# 822 0.575419 0.527500 0.798883 0.800000
# 166 0.160615 0.562500 0.315642 0.875000
#
# 822
# =============
# Img_003_0391.txt
# 822 0.370605 0.435000 0.215190 0.550000
#
# 822
# =============
# Img_003_0392.txt
# 822 0.456399 0.550000 0.654008 0.420000
# 166 0.471871 0.295000 0.383966 0.440000
#
# 822
# =============
# Img_003_0394.txt
# 822 0.452883 0.497500 0.675105 0.795000
# 166 0.300281 0.497500 0.237693 0.520000
# 166 0.694093 0.497500 0.209564 0.345000
#
# 822
# =============
# Img_003_0395.txt
# 822 0.545326 0.590000 0.745042 0.820000
# 166 0.131728 0.596250 0.257790 0.767500
# 166 0.915014 0.750000 0.169972 0.500000
#
# 822
# =============
# Img_003_0396.txt
# 822 0.627820 0.525000 0.689223 0.950000
# 166 0.200501 0.357500 0.395990 0.380000
# 166 0.170426 0.770000 0.175439 0.460000
#
# 822
# =============
# Img_003_0398.txt
# 822 0.450915 0.288750 0.405990 0.232500
# 166 0.258735 0.522500 0.327787 0.205000
#
# 822
# =============
# Img_003_0399.txt
# 20 0.534110 0.518750 0.662230 0.547500
#
# 20
# =============
# Img_003_0400.txt
# 822 0.472574 0.497500 0.894515 0.895000
#
# 822
# =============
# Img_003_0401.txt
# 822 0.325516 0.825000 0.467167 0.350000
# 822 0.080675 0.432500 0.157598 0.370000
# 822 0.893996 0.491250 0.212008 0.782500
# 166 0.696060 0.610000 0.187617 0.385000
# 780 0.488743 0.377500 0.440901 0.435000
#
# 822
# =============
# Img_003_0402.txt
# 822 0.470919 0.423750 0.409006 0.462500
# 780 0.615385 0.161250 0.502814 0.197500
# 166 0.642589 0.712500 0.230769 0.205000
#
# 822
# =============
# Img_003_0404.txt
# 822 0.476667 0.602500 0.443333 0.760000
# 684 0.819167 0.535000 0.338333 0.445000
#
# 822
# =============
# Img_003_0405.txt
# 822 0.316135 0.586250 0.369606 0.372500
# 770 0.520638 0.312500 0.377111 0.145000
#
# 822
# =============
# Img_003_0406.txt
# 822 0.250000 0.553750 0.450000 0.292500
# 822 0.810714 0.572500 0.378571 0.235000
# 822 0.384821 0.820000 0.066071 0.080000
# 780 0.245536 0.725000 0.130357 0.145000
# 780 0.780357 0.761250 0.164286 0.182500
#
# 822
# =============
# Img_003_0409.txt
# 822 0.589118 0.507500 0.660413 0.660000
#
# 822
# =============
# Img_003_0410.txt
# 822 0.533771 0.521250 0.696060 0.732500
#
# 822
# =============
# Img_003_0411.txt
# 822 0.498333 0.520000 0.990000 0.545000
#
# 822
# =============
# Img_003_0413.txt
# 822 0.545833 0.535000 0.751667 0.575000
#
# 822
# =============
# Img_003_0414.txt
# 822 0.430000 0.467500 0.480000 0.435000
#
# 822
# =============
# Img_003_0415.txt
# 822 0.434334 0.207500 0.647280 0.375000
# 166 0.878987 0.345000 0.242026 0.555000
#
# 822
# =============
# Img_003_0417.txt
# 822 0.560935 0.503750 0.878130 0.707500
#
# 822
# =============
# Img_003_0418.txt
# 822 0.570000 0.380000 0.266667 0.430000
# 822 0.122500 0.616250 0.241667 0.252500
# 166 0.213333 0.652500 0.423333 0.655000
# 780 0.269167 0.291250 0.348333 0.347500
#
# 822
# =============
# Img_003_0419.txt
# 822 0.510000 0.376250 0.563333 0.432500
# 166 0.263333 0.706250 0.330000 0.387500
# 780 0.759167 0.697500 0.448333 0.475000
#
# 822
# =============
# Img_003_0420.txt
# 822 0.560000 0.565000 0.880000 0.870000
#
# 822
# =============
# Img_003_0421.txt
# 822 0.514096 0.545000 0.971808 0.705000
#
# 822
# =============
# Img_003_0422.txt
# 822 0.477612 0.461250 0.802653 0.817500
#
# 822
# =============
# Img_003_0423.txt
# 822 0.476783 0.477500 0.880597 0.715000
# 166 0.535655 0.813750 0.371476 0.362500
# 780 0.828358 0.770000 0.320066 0.395000
#
# 822
# =============
# Img_003_0424.txt
# 822 0.562852 0.296250 0.330206 0.302500
#
# 822
# =============
# Img_003_0425.txt
# 822 0.513267 0.361250 0.512438 0.327500
#
# 822
# =============
# Img_003_0426.txt
# 822 0.601667 0.320000 0.603333 0.360000
# 437 0.612500 0.471250 0.081667 0.222500
# 437 0.885000 0.455000 0.156667 0.380000
# 166 0.334167 0.113750 0.278333 0.182500
#
# 822
# =============
# Img_003_0427.txt
# 822 0.494371 0.423750 0.984991 0.627500
#
# 822
# =============
# Img_003_0428.txt
# 822 0.600375 0.487500 0.360225 0.370000
#
# 822
# =============
# Img_003_0429.txt
# 822 0.791667 0.517500 0.260000 0.460000
# 166 0.536667 0.506250 0.343333 0.407500
# 780 0.221667 0.611250 0.403333 0.447500
#
# 822
# =============
# Img_003_0430.txt
# 822 0.496667 0.755000 0.816667 0.270000
# 780 0.529167 0.455000 0.371667 0.465000
#
# 822
# =============
# Img_003_0431.txt
# 822 0.331469 0.530000 0.402797 0.360000
#
# 822
# =============
# Img_003_0432.txt
# 822 0.549249 0.485000 0.694491 0.500000
#
# 822
# =============
# Img_003_0433.txt
# 822 0.708255 0.317500 0.583490 0.555000
#
# 822
# =============
# Img_003_0434.txt
# 822 0.474490 0.355000 0.414966 0.305000
# 697 0.170918 0.612500 0.185374 0.275000
# 780 0.457483 0.746250 0.360544 0.337500
# 166 0.791667 0.601250 0.202381 0.312500
# 437 0.749150 0.273750 0.229592 0.297500
# 437 0.563776 0.135000 0.215986 0.095000
#
# 822
# =============
# Img_003_0435.txt
# 822 0.498124 0.441250 0.463415 0.592500
#
# 822
# =============
# Img_003_0436.txt
# 822 0.430124 0.548750 0.636646 0.442500
#
# 822
# =============
# Img_003_0437.txt
# 822 0.500832 0.522500 0.688852 0.710000
#
# 822
# =============
# Img_003_0438.txt
# 822 0.438115 0.503750 0.665260 0.937500
# 166 0.589311 0.461250 0.109705 0.362500
# 780 0.443038 0.410000 0.174402 0.265000
#
# 822
# =============
# Img_003_0439.txt
# 822 0.191370 0.448750 0.360225 0.377500
# 166 0.533771 0.372500 0.309568 0.200000
#
# 822
# =============
# Img_003_0440.txt
# 822 0.494830 0.396250 0.723781 0.742500
#
# 822
# =============
# Img_003_0441.txt
# 822 0.483386 0.540000 0.213608 0.390000
#
# 822
# =============
# Img_003_0442.txt
# 822 0.446841 0.357500 0.884438 0.500000
#
# 822
# =============
# Img_003_0443.txt
# 822 0.610000 0.233750 0.708571 0.432500
# 822 0.493571 0.567500 0.352857 0.355000
#
# 822
# =============
# Img_003_0444.txt
# 822 0.434880 0.327500 0.528443 0.505000
#
# 822
# =============
# Img_003_0445.txt
# 822 0.478163 0.336250 0.495482 0.517500
#
# 822
# =============
# Img_003_0446.txt
# 822 0.527736 0.411250 0.608696 0.747500
#
# 822
# =============
# Img_003_0447.txt
# 822 0.447702 0.411250 0.882726 0.787500
#
# 822
# =============
# Img_003_0448.txt
# 822 0.427861 0.631250 0.809287 0.497500
#
# 822
# =============
# Img_003_0449.txt
# 822 0.461028 0.520000 0.673300 0.780000
#
# 822
# =============
# Img_003_0450.txt
# 822 0.482587 0.520000 0.786070 0.875000
#
# 822
# =============
# Img_003_0451.txt
# 822 0.553471 0.568750 0.810507 0.427500
#
# 822
# =============
# Img_003_0452.txt
# 20 0.555833 0.343750 0.341667 0.232500
# 780 0.527500 0.772500 0.358333 0.385000
# 224 0.855833 0.632500 0.235000 0.190000
#
# 20
# =============
# Img_003_0453.txt
# 822 0.529851 0.567500 0.544776 0.715000
# 166 0.486940 0.161250 0.432836 0.187500
#
# 822
# =============
# Img_003_0454.txt
# 822 0.578203 0.520000 0.554077 0.960000
# 822 0.183028 0.738750 0.346090 0.522500
# 166 0.108985 0.472500 0.214642 0.435000
#
# 822
# =============
# Img_003_0455.txt
# 822 0.508303 0.592500 0.939114 0.800000
#
# 822
# =============
# Img_003_0456.txt
# 822 0.455696 0.458750 0.323488 0.667500
# 166 0.697609 0.470000 0.202532 0.285000
#
# 822
# =============
# Img_003_0457.txt
# 822 0.563790 0.335000 0.718574 0.450000
# 780 0.763602 0.702500 0.427767 0.455000
# 166 0.440901 0.805000 0.307692 0.290000
#
# 822
# =============
# Img_003_0458.txt
# 822 0.264540 0.581250 0.285178 0.747500
# 780 0.657598 0.193750 0.639775 0.342500
#
# 822
# =============
# Img_003_0460.txt
# 822 0.304878 0.485000 0.587242 0.810000
#
# 822
# =============
# Img_003_0461.txt
# 822 0.508580 0.481250 0.982839 0.927500
#
# 822
# =============
# Img_003_0462.txt
# 822 0.467167 0.495000 0.926829 0.905000
# 166 0.309568 0.327500 0.409006 0.340000
#
# 822
# =============
# Img_003_0463.txt
# 822 0.500000 0.392500 0.445183 0.405000
# 166 0.339701 0.606250 0.267442 0.357500
#
# 822
# =============
# Img_003_0464.txt
# 822 0.503752 0.590000 0.992495 0.820000
#
# 822
# =============
# Img_003_0465.txt
# 822 0.454545 0.541250 0.692967 0.437500
# 780 0.279588 0.265000 0.315609 0.280000
#
# 822
# =============
# Img_003_0466.txt
# 822 0.527454 0.502500 0.931780 0.995000
#
# 822
# =============
# Img_003_0467.txt
# 822 0.498596 0.577500 0.994382 0.830000
#
# 822
# =============
# Img_003_0468.txt
# 822 0.340532 0.890000 0.641196 0.205000
# 822 0.600498 0.518750 0.151163 0.147500
#
# 822
# =============
# Img_003_0469.txt
# 822 0.514860 0.660000 0.571678 0.220000
# 780 0.530594 0.392500 0.319930 0.255000
#
# 822
# =============
# Img_003_0470.txt
# 780 0.579545 0.530000 0.526224 0.300000
# 822 0.611014 0.763750 0.452797 0.267500
# 822 0.155594 0.512500 0.272727 0.445000
#
# 780
# =============
# Img_003_0473.txt
# 822 0.501250 0.326250 0.997500 0.647500
#
# 822
# =============
# Img_003_0474.txt
# 822 0.551495 0.342500 0.478405 0.365000
# 822 0.358804 0.727500 0.392027 0.420000
# 166 0.148671 0.430000 0.294020 0.315000
# 437 0.814784 0.765000 0.350498 0.470000
#
# 822
# =============
# Img_003_0475.txt
# 822 0.501658 0.485000 0.996683 0.585000
#
# 822
# =============
# Img_003_0476.txt
# 822 0.500833 0.521250 0.421667 0.392500
#
# 822
# =============
# Img_003_0478.txt
# 822 0.475833 0.428750 0.415000 0.482500
# 822
# =============
# Img_003_0479.txt
# 822 0.598333 0.486250 0.376667 0.662500
#
# 822
# =============
# Img_003_0480.txt
# 822 0.588870 0.406250 0.513289 0.732500
# 166 0.263289 0.550000 0.224252 0.540000
# 437 0.924419 0.630000 0.151163 0.425000
#
# 822
# =============
# Img_003_0482.txt
# 822 0.460000 0.402500 0.310000 0.320000
#
# 822
# =============
# Img_003_0483.txt
# 822 0.605833 0.395000 0.418333 0.490000
# 166 0.332500 0.555000 0.231667 0.395000
#
# 822
# =============
# Img_003_0484.txt
# 822 0.500000 0.456250 0.286667 0.377500
#
# 822
# =============
# Img_003_0485.txt
# 822 0.527409 0.522500 0.938538 0.950000
#
# 822
# =============
# Img_003_0486.txt
# 822 0.497500 0.430000 0.418333 0.420000
#
# 822
# =============
# Img_003_0487.txt
# 822 0.529167 0.520000 0.435000 0.395000
#
# 822
# =============
# Img_003_0488.txt
# 822 0.498333 0.405000 0.340000 0.520000
#
# 822
# =============
# Img_003_0489.txt
# 822 0.472500 0.540000 0.608333 0.850000
#
# 822
# =============
# Img_003_0490.txt
# 822 0.540833 0.378750 0.251667 0.382500
#
# 822
# =============
# Img_003_0491.txt
# 822 0.515000 0.415000 0.266667 0.335000
#
# 822
# =============
# Img_003_0492.txt
# 822 0.762500 0.521250 0.475000 0.817500
# 822 0.086667 0.687500 0.130000 0.225000
# 166 0.403333 0.645000 0.420000 0.310000
#
# 822
# =============
# Img_003_0493.txt
# 822 0.500000 0.485000 0.483333 0.580000
#
# 822
# =============
# Img_003_0495.txt
# 822 0.493333 0.553750 0.953333 0.757500
#
# 822
# =============
# Img_003_0496.txt
# 822 0.508306 0.532500 0.983389 0.470000
#
# 822
# =============
# Img_003_0497.txt
# 822 0.502492 0.318750 0.705980 0.412500
#
# 822
# =============
# Img_003_0498.txt
# 822 0.530731 0.366250 0.868771 0.487500
# 166 0.451827 0.803750 0.568106 0.317500
#
# 822
# =============
# Img_003_0499.txt
# 822 0.496678 0.312500 0.980066 0.565000
#
# 822
# =============
# Img_003_0500.txt
# 822 0.489167 0.567500 0.298333 0.220000
# 437 0.190833 0.798750 0.241667 0.227500
#
# 822
# =============
# Img_003_0501.txt
# 822 0.621849 0.350000 0.616246 0.455000
#
# 822
# =============
# Img_003_0502.txt
# 822 0.518762 0.491250 0.793621 0.812500
#
# 822
# =============
# Img_003_0503.txt
# 822 0.502500 0.603750 0.995000 0.772500
# 166 0.155833 0.118750 0.305000 0.222500
#
# 822
# =============
# Img_003_0504.txt
# 822 0.568820 0.496250 0.592697 0.657500
# 166 0.156601 0.368750 0.265449 0.347500
#
# 822
# =============
# Img_003_0505.txt
# 166 0.186047 0.503750 0.275748 0.352500
# 822 0.078904 0.791250 0.151163 0.292500
# 822 0.416944 0.488750 0.225914 0.382500
#
# 166
# =============
# Img_003_0506.txt
# 822 0.532833 0.375000 0.243902 0.460000
# 437 0.356473 0.443750 0.101313 0.222500
# 437 0.682927 0.256250 0.116323 0.162500
# 166 0.419325 0.167500 0.298311 0.325000
# 166 0.591932 0.766250 0.560976 0.387500
#
# 822
# =============
# Img_003_0507.txt
# 20 0.441839 0.556250 0.872420 0.762500
#
# 20
# =============
# Img_003_0508.txt
# 822 0.524390 0.495000 0.594747 0.480000
# 166 0.469043 0.146250 0.318949 0.287500
#
# 822
# =============
# Img_003_0509.txt
# 822 0.579737 0.525000 0.547842 0.585000
# 166 0.377111 0.220000 0.135084 0.215000
# 166 0.747655 0.246250 0.181989 0.202500
#
# 822
# =============
# Img_003_0510.txt
# 822 0.677298 0.178750 0.645403 0.337500
#
# 822
# =============
# Img_003_0511.txt
# 20 0.504139 0.365000 0.534768 0.485000
#
# 20
# =============
# Img_003_0512.txt
# 822 0.360833 0.563750 0.441667 0.257500
#
# 822
# =============
# Img_003_0513.txt
# 822 0.462559 0.462500 0.772231 0.745000
# 780 0.500000 0.342500 0.360374 0.335000
#
# 822
# =============
# Img_003_0514.txt
# 822 0.458724 0.415000 0.808630 0.735000
#
# 822
# =============
# Img_003_0515.txt
# 822 0.500000 0.415000 0.981238 0.635000
#
# 822
# =============
# Img_003_0516.txt
# ...
# "Img_015_0003.jpg" has been copied in new folder!
# "Img_015_0006.jpg" has been copied in new folder!
# "Img_015_0008.jpg" has been copied in new folder!
# "Img_015_0010.jpg" has been copied in new folder!
# "Img_015_0012.jpg" has been copied in new folder!
# "Img_015_0015.jpg" has been copied in new folder!
# "Img_015_0016.jpg" has been copied in new folder!
# "Img_015_0017.jpg" has been copied in new folder!
# "Img_015_0018.jpg" has been copied in new folder!
# "Img_015_0019.jpg" has been copied in new folder!
# "Img_015_0020.jpg" has been copied in new folder!
# "Img_015_0023.jpg" has been copied in new folder!
# "Img_015_0024.jpg" has been copied in new folder!
# "Img_015_0025.jpg" has been copied in new folder!
# "Img_015_0026.jpg" has been copied in new folder!
# "Img_015_0027.jpg" has been copied in new folder!
# "Img_015_0028.jpg" has been copied in new folder!
# "Img_015_0029.jpg" has been copied in new folder!
# "Img_015_0030.jpg" has been copied in new folder!
# "Img_015_0031.jpg" has been copied in new folder!
# "Img_015_0038.jpg" has been copied in new folder!
# "Img_015_0041.jpg" has been copied in new folder!
# "Img_015_0042.jpg" has been copied in new folder!
# "Img_015_0043.jpg" has been copied in new folder!
# "Img_015_0044.jpg" has been copied in new folder!
# "Img_015_0047.jpg" has been copied in new folder!
# "Img_015_0049.jpg" has been copied in new folder!
# "Img_015_0051.jpg" has been copied in new folder!
# "Img_015_0054.jpg" has been copied in new folder!
# "Img_015_0059.jpg" has been copied in new folder!
# "Img_015_0060.jpg" has been copied in new folder!
# "Img_015_0061.jpg" has been copied in new folder!
# "Img_015_0064.jpg" has been copied in new folder!
# "Img_015_0065.jpg" has been copied in new folder!
# "Img_015_0067.jpg" has been copied in new folder!
# "Img_015_0070.jpg" has been copied in new folder!
# "Img_015_0072.jpg" has been copied in new folder!
# "Img_015_0074.jpg" has been copied in new folder!
# "Img_015_0076.jpg" has been copied in new folder!
# "Img_015_0077.jpg" has been copied in new folder!
# "Img_015_0079.jpg" has been copied in new folder!
# "Img_015_0081.jpg" has been copied in new folder!
# "Img_015_0083.jpg" has been copied in new folder!
# "Img_015_0084.jpg" has been copied in new folder!
# "Img_015_0085.jpg" has been copied in new folder!
# "Img_015_0089.jpg" has been copied in new folder!
# "Img_015_0093.jpg" has been copied in new folder!
# "Img_015_0094.jpg" has been copied in new folder!
# "Img_015_0095.jpg" has been copied in new folder!
# "Img_015_0097.jpg" has been copied in new folder!
# "Img_015_0098.jpg" has been copied in new folder!
# "Img_015_0103.jpg" has been copied in new folder!
# "Img_015_0106.jpg" has been copied in new folder!
# "Img_015_0107.jpg" has been copied in new folder!
# "Img_015_0108.jpg" has been copied in new folder!
# "Img_015_0112.jpg" has been copied in new folder!
# "Img_015_0113.jpg" has been copied in new folder!
# "Img_015_0114.jpg" has been copied in new folder!
# "Img_015_0115.jpg" has been copied in new folder!
# "Img_015_0117.jpg" has been copied in new folder!
# "Img_015_0120.jpg" has been copied in new folder!
# "Img_015_0121.jpg" has been copied in new folder!
# "Img_015_0122.jpg" has been copied in new folder!
# "Img_015_0123.jpg" has been copied in new folder!
# "Img_015_0125.jpg" has been copied in new folder!
# "Img_015_0126.jpg" has been copied in new folder!
# "Img_015_0128.jpg" has been copied in new folder!
# "Img_015_0129.jpg" has been copied in new folder!
# "Img_015_0130.jpg" has been copied in new folder!
# "Img_015_0131.jpg" has been copied in new folder!
# "Img_015_0132.jpg" has been copied in new folder!
# "Img_015_0134.jpg" has been copied in new folder!
# "Img_015_0142.jpg" has been copied in new folder!
# "Img_015_0143.jpg" has been copied in new folder!
# "Img_015_0150.jpg" has been copied in new folder!
# "Img_015_0154.jpg" has been copied in new folder!
# "Img_015_0155.jpg" has been copied in new folder!
# "Img_015_0160.jpg" has been copied in new folder!
# "Img_015_0162.jpg" has been copied in new folder!
# "Img_015_0163.jpg" has been copied in new folder!
# "Img_015_0165.jpg" has been copied in new folder!
# "Img_015_0168.jpg" has been copied in new folder!
# "Img_015_0170.jpg" has been copied in new folder!
# "Img_015_0173.jpg" has been copied in new folder!
# "Img_015_0175.jpg" has been copied in new folder!
# "Img_015_0176.jpg" has been copied in new folder!
# "Img_015_0177.jpg" has been copied in new folder!
# "Img_015_0179.jpg" has been copied in new folder!
# "Img_015_0180.jpg" has been copied in new folder!
# "Img_015_0181.jpg" has been copied in new folder!
# "Img_015_0189.jpg" has been copied in new folder!
# "Img_015_0191.jpg" has been copied in new folder!
# "Img_015_0192.jpg" has been copied in new folder!
# "Img_015_0193.jpg" has been copied in new folder!
# "Img_015_0200.jpg" has been copied in new folder!
# "Img_015_0202.jpg" has been copied in new folder!
# "Img_015_0203.jpg" has been copied in new folder!
# "Img_015_0204.jpg" has been copied in new folder!
# "Img_015_0210.jpg" has been copied in new folder!
# "Img_015_0215.jpg" has been copied in new folder!
# "Img_015_0216.jpg" has been copied in new folder!
# "Img_015_0219.jpg" has been copied in new folder!
# "Img_015_0220.jpg" has been copied in new folder!
# "Img_015_0232.jpg" has been copied in new folder!
# "Img_015_0234.jpg" has been copied in new folder!
# "Img_015_0236.jpg" has been copied in new folder!
# "Img_015_0241.jpg" has been copied in new folder!
# "Img_015_0245.jpg" has been copied in new folder!
# "Img_015_0253.jpg" has been copied in new folder!
# "Img_015_0260.jpg" has been copied in new folder!
# "Img_015_0261.jpg" has been copied in new folder!
# "Img_015_0264.jpg" has been copied in new folder!
# "Img_015_0265.jpg" has been copied in new folder!
# "Img_015_0269.jpg" has been copied in new folder!
# "Img_015_0270.jpg" has been copied in new folder!
# "Img_015_0272.jpg" has been copied in new folder!
# "Img_015_0275.jpg" has been copied in new folder!
# "Img_015_0276.jpg" has been copied in new folder!
# "Img_015_0286.jpg" has been copied in new folder!
# "Img_015_0288.jpg" has been copied in new folder!
# "Img_015_0298.jpg" has been copied in new folder!
# "Img_015_0304.jpg" has been copied in new folder!
# "Img_015_0305.jpg" has been copied in new folder!
# "Img_015_0312.jpg" has been copied in new folder!
# "Img_015_0317.jpg" has been copied in new folder!
# "Img_015_0319.jpg" has been copied in new folder!
# "Img_015_0338.jpg" has been copied in new folder!
# "Img_015_0339.jpg" has been copied in new folder!
# "Img_015_0340.jpg" has been copied in new folder!
# "Img_015_0341.jpg" has been copied in new folder!
# "Img_015_0342.jpg" has been copied in new folder!
# "Img_015_0343.jpg" has been copied in new folder!
# "Img_015_0355.jpg" has been copied in new folder!
# "Img_015_0362.jpg" has been copied in new folder!
# "Img_015_0366.jpg" has been copied in new folder!
# "Img_015_0370.jpg" has been copied in new folder!
# "Img_015_0379.jpg" has been copied in new folder!
# "Img_015_0393.jpg" has been copied in new folder!
# "Img_015_0398.jpg" has been copied in new folder!
# "Img_015_0403.jpg" has been copied in new folder!
# "Img_015_0407.jpg" has been copied in new folder!
# "Img_015_0410.jpg" has been copied in new folder!
# "Img_015_0412.jpg" has been copied in new folder!
# "Img_015_0413.jpg" has been copied in new folder!
# "Img_015_0414.jpg" has been copied in new folder!
# "Img_015_0419.jpg" has been copied in new folder!
# "Img_015_0420.jpg" has been copied in new folder!
# "Img_015_0424.jpg" has been copied in new folder!
# "Img_015_0426.jpg" has been copied in new folder!
# "Img_015_0428.jpg" has been copied in new folder!
# "Img_015_0433.jpg" has been copied in new folder!
# "Img_015_0435.jpg" has been copied in new folder!
# "Img_015_0441.jpg" has been copied in new folder!
# "Img_015_0443.jpg" has been copied in new folder!
# "Img_015_0449.jpg" has been copied in new folder!
# "Img_015_0450.jpg" has been copied in new folder!
# "Img_015_0452.jpg" has been copied in new folder!
# "Img_015_0459.jpg" has been copied in new folder!
# "Img_015_0475.jpg" has been copied in new folder!
# "Img_015_0476.jpg" has been copied in new folder!
# "Img_015_0481.jpg" has been copied in new folder!
# "Img_015_0483.jpg" has been copied in new folder!
# "Img_015_0485.jpg" has been copied in new folder!
# "Img_015_0489.jpg" has been copied in new folder!
# "Img_015_0491.jpg" has been copied in new folder!
# "Img_015_0492.jpg" has been copied in new folder!
# "Img_015_0493.jpg" has been copied in new folder!
# "Img_015_0498.jpg" has been copied in new folder!
# "Img_015_0499.jpg" has been copied in new folder!
# "Img_015_0500.jpg" has been copied in new folder!
# "Img_015_0501.jpg" has been copied in new folder!
# "Img_015_0505.jpg" has been copied in new folder!
# "Img_015_0510.jpg" has been copied in new folder!
# "Img_015_0517.jpg" has been copied in new folder!
# "Img_015_0547.jpg" has been copied in new folder!
# "Img_015_0551.jpg" has been copied in new folder!
# "Img_015_0552.jpg" has been copied in new folder!
# "Img_015_0557.jpg" has been copied in new folder!
# "Img_015_0560.jpg" has been copied in new folder!
# "Img_015_0562.jpg" has been copied in new folder!
# "Img_015_0563.jpg" has been copied in new folder!
# "Img_015_0565.jpg" has been copied in new folder!
# "Img_015_0571.jpg" has been copied in new folder!
# "Img_015_0572.jpg" has been copied in new folder!
# "Img_015_0580.jpg" has been copied in new folder!
# "Img_015_0584.jpg" has been copied in new folder!
# "Img_015_0587.jpg" has been copied in new folder!
# "Img_015_0594.jpg" has been copied in new folder!
# "Img_015_0597.jpg" has been copied in new folder!
# "Img_015_0598.jpg" has been copied in new folder!
# "Img_015_0600.jpg" has been copied in new folder!
# "Img_015_0602.jpg" has been copied in new folder!
# "Img_015_0603.jpg" has been copied in new folder!
# "Img_015_0607.jpg" has been copied in new folder!
# "Img_015_0609.jpg" has been copied in new folder!
# "Img_015_0613.jpg" has been copied in new folder!
# "Img_015_0614.jpg" has been copied in new folder!
# "Img_015_0621.jpg" has been copied in new folder!
# "Img_015_0622.jpg" has been copied in new folder!
# "Img_015_0626.jpg" has been copied in new folder!
# "Img_015_0632.jpg" has been copied in new folder!
# "Img_015_0634.jpg" has been copied in new folder!
# "Img_015_0636.jpg" has been copied in new folder!
# "Img_015_0637.jpg" has been copied in new folder!
# "Img_015_0638.jpg" has been copied in new folder!
# "Img_015_0640.jpg" has been copied in new folder!
# "Img_015_0641.jpg" has been copied in new folder!
# "Img_015_0643.jpg" has been copied in new folder!
# "Img_015_0648.jpg" has been copied in new folder!
# "Img_015_0653.jpg" has been copied in new folder!
# "Img_015_0656.jpg" has been copied in new folder!
# "Img_015_0657.jpg" has been copied in new folder!
# "Img_015_0661.jpg" has been copied in new folder!
# "Img_015_0664.jpg" has been copied in new folder!
# "Img_015_0673.jpg" has been copied in new folder!
# "Img_015_0678.jpg" has been copied in new folder!
# "Img_015_0679.jpg" has been copied in new folder!
# "Img_015_0680.jpg" has been copied in new folder!
# "Img_015_0686.jpg" has been copied in new folder!
# "Img_015_0687.jpg" has been copied in new folder!
# "Img_015_0691.jpg" has been copied in new folder!
# "Img_015_0696.jpg" has been copied in new folder!
# "Img_015_0701.jpg" has been copied in new folder!
# "Img_015_0711.jpg" has been copied in new folder!
# "Img_015_0718.jpg" has been copied in new folder!
# "Img_015_0722.jpg" has been copied in new folder!
# "Img_015_0729.jpg" has been copied in new folder!
# "Img_015_0731.jpg" has been copied in new folder!
# "Img_015_0732.jpg" has been copied in new folder!
# "Img_015_0737.jpg" has been copied in new folder!
# "Img_015_0741.jpg" has been copied in new folder!
# "Img_015_0745.jpg" has been copied in new folder!
# "Img_015_0750.jpg" has been copied in new folder!
# "Img_015_0752.jpg" has been copied in new folder!
# "Img_015_0754.jpg" has been copied in new folder!
# "Img_015_0755.jpg" has been copied in new folder!
# "Img_015_0758.jpg" has been copied in new folder!
# "Img_015_0759.jpg" has been copied in new folder!
# "Img_015_0760.jpg" has been copied in new folder!
# "Img_015_0775.jpg" has been copied in new folder!
# "Img_015_0780.jpg" has been copied in new folder!
# "Img_015_0785.jpg" has been copied in new folder!
# "Img_015_0797.jpg" has been copied in new folder!
# "Img_015_0798.jpg" has been copied in new folder!
# "Img_015_0801.jpg" has been copied in new folder!
# "Img_015_0802.jpg" has been copied in new folder!
# "Img_015_0806.jpg" has been copied in new folder!
# "Img_015_0807.jpg" has been copied in new folder!
# "Img_015_0813.jpg" has been copied in new folder!
# "Img_015_0814.jpg" has been copied in new folder!
# "Img_015_0821.jpg" has been copied in new folder!
# "Img_015_0824.jpg" has been copied in new folder!
# "Img_015_0825.jpg" has been copied in new folder!
# "Img_015_0827.jpg" has been copied in new folder!
# "Img_015_0832.jpg" has been copied in new folder!
# "Img_015_0835.jpg" has been copied in new folder!
# "Img_015_0840.jpg" has been copied in new folder!
# "Img_015_0841.jpg" has been copied in new folder!
# "Img_015_0845.jpg" has been copied in new folder!
# "Img_015_0846.jpg" has been copied in new folder!
# "Img_015_0850.jpg" has been copied in new folder!
# "Img_015_0856.jpg" has been copied in new folder!
# "Img_015_0857.jpg" has been copied in new folder!
# "Img_015_0862.jpg" has been copied in new folder!
# "Img_015_0863.jpg" has been copied in new folder!
# "Img_015_0864.jpg" has been copied in new folder!
# "Img_015_0869.jpg" has been copied in new folder!
# "Img_015_0870.jpg" has been copied in new folder!
# "Img_015_0871.jpg" has been copied in new folder!
# "Img_015_0883.jpg" has been copied in new folder!
# "Img_015_0888.jpg" has been copied in new folder!
# "Img_015_0904.jpg" has been copied in new folder!
# "Img_015_0905.jpg" has been copied in new folder!
# "Img_015_0906.jpg" has been copied in new folder!
# "Img_015_0907.jpg" has been copied in new folder!
# "Img_015_0911.jpg" has been copied in new folder!
# "Img_015_0913.jpg" has been copied in new folder!
# "Img_015_0914.jpg" has been copied in new folder!
# "Img_015_0919.jpg" has been copied in new folder!
# "Img_015_0922.jpg" has been copied in new folder!
# "Img_015_0926.jpg" has been copied in new folder!
# "Img_015_0927.jpg" has been copied in new folder!
# "Img_015_0928.jpg" has been copied in new folder!
# "Img_015_0929.jpg" has been copied in new folder!
# "Img_015_0931.jpg" has been copied in new folder!
# "Img_015_0933.jpg" has been copied in new folder!
# "Img_015_0937.jpg" has been copied in new folder!
# "Img_015_0939.jpg" has been copied in new folder!
# "Img_015_0941.jpg" has been copied in new folder!
# "Img_015_0943.jpg" has been copied in new folder!
# "Img_015_0947.jpg" has been copied in new folder!
# "Img_015_0953.jpg" has been copied in new folder!
# "Img_015_0956.jpg" has been copied in new folder!
# "Img_015_0958.jpg" has been copied in new folder!
# "Img_015_0960.jpg" has been copied in new folder!
# "Img_015_0961.jpg" has been copied in new folder!
# "Img_015_0962.jpg" has been copied in new folder!
# "Img_015_0966.jpg" has been copied in new folder!
# "Img_015_0967.jpg" has been copied in new folder!
# "Img_015_0968.jpg" has been copied in new folder!
# "Img_015_0969.jpg" has been copied in new folder!
# "Img_015_0970.jpg" has been copied in new folder!
# "Img_015_0973.jpg" has been copied in new folder!
# "Img_015_0974.jpg" has been copied in new folder!
# "Img_015_0975.jpg" has been copied in new folder!
# "Img_015_0976.jpg" has been copied in new folder!
# "Img_015_0977.jpg" has been copied in new folder!
# "Img_015_0978.jpg" has been copied in new folder!
# "Img_015_0979.jpg" has been copied in new folder!
# "Img_015_0980.jpg" has been copied in new folder!
# "Img_015_0981.jpg" has been copied in new folder!
# "Img_015_0984.jpg" has been copied in new folder!
# "Img_015_0987.jpg" has been copied in new folder!
# "Img_015_0988.jpg" has been copied in new folder!
# "Img_015_0992.jpg" has been copied in new folder!
# "Img_015_0993.jpg" has been copied in new folder!
# "Img_015_0994.jpg" has been copied in new folder!
# "Img_015_0996.jpg" has been copied in new folder!
# "Img_015_0999.jpg" has been copied in new folder!
